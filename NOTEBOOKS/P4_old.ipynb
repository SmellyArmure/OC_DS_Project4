# %% [markdown]
# # "Anticipez les besoins en consommation électrique de bâtiments"
# _Notebook_

# %% [markdown]
# ## 0 Preliminaries

# %% [markdown]
# ### 0.0 Importing Packages and Modules

# %% [markdown]
# Checking whether the notebook is on Colab or PC

# %%
import sys
is_colab = 'google.colab' in sys.modules
is_colab, sys.executable
# Out:
# (True, '/usr/bin/python3')

# %% [markdown]
# Mounting my Drive if on colab

# %%
if is_colab==True:
    from google.colab import files, output, drive
    drive.mount('/gdrive')
    # %cd /gdrive
    print("You're on Google Colab")
else:
    print("You're on a PC")
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive
# You're on Google Colab

# %% [markdown]
# Noticing user about files that has to be in the current working directory.

# %%
def file_required(file_name):
    if os.path.exists(os.getcwd()+"/"+file_name):
        print("OK, loading "+file_name+"\
                           from the current working directory ...")
    else:
        print("Please, put "+file_name+"\
                           in the current working directory")

# %% [markdown]
# Installations and importations required for Google Colab version.

# %%
# !pip freeze > requirements.txt
# Out:
# /bin/bash: requirements.txt: Operation not supported

# %%
# !pip install mlxtend==0.17.2
# !pip install scikit-learn==0.23.1

# %%
import os

if is_colab==True:
    if os.getcwd()!='/gdrive/My Drive/--DATA SCIENCE/PROJET4':
        os.chdir('My Drive/--DATA SCIENCE/PROJET4')
    # !pip install -r requirements.txt
else:
    # make sure 'P4_functions.py' is in the current working directory
    file_required('/P4_functions.py')
    file_required('requirements.txt')
    # !pip install -r requirements.txt
# Out:
# Requirement already satisfied: absl-py==0.9.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 1)) (0.9.0)
# Requirement already satisfied: alabaster==0.7.12 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 2)) (0.7.12)
# Requirement already satisfied: albumentations==0.1.12 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 3)) (0.1.12)
# Requirement already satisfied: altair==4.1.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 4)) (4.1.0)
# Requirement already satisfied: asgiref==3.2.9 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 5)) (3.2.9)
# Requirement already satisfied: astor==0.8.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 6)) (0.8.1)
# Requirement already satisfied: astropy==4.0.1.post1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 7)) (4.0.1.post1)
# Requirement already satisfied: astunparse==1.6.3 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 8)) (1.6.3)
# Requirement already satisfied: atari-py==0.2.6 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 9)) (0.2.6)
# Requirement already satisfied: atomicwrites==1.4.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 10)) (1.4.0)
# Requirement already satisfied: attrs==19.3.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 11)) (19.3.0)
# Requirement already satisfied: audioread==2.1.8 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 12)) (2.1.8)
# Requirement already satisfied: autograd==1.3 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 13)) (1.3)
# Requirement already satisfied: Babel==2.8.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 14)) (2.8.0)
# Requirement already satisfied: backcall==0.2.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 15)) (0.2.0)
# Requirement already satisfied: beautifulsoup4==4.6.3 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 16)) (4.6.3)
# Requirement already satisfied: bleach==3.1.5 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 17)) (3.1.5)
# Requirement already satisfied: blis==0.4.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 18)) (0.4.1)
# Requirement already satisfied: bokeh==1.4.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 19)) (1.4.0)
# Requirement already satisfied: boto==2.49.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 20)) (2.49.0)
# Requirement already satisfied: boto3==1.14.5 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 21)) (1.14.5)
# Requirement already satisfied: botocore==1.17.5 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 22)) (1.17.5)
# Requirement already satisfied: Bottleneck==1.3.2 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 23)) (1.3.2)
# Requirement already satisfied: branca==0.4.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 24)) (0.4.1)
# Requirement already satisfied: bs4==0.0.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 25)) (0.0.1)
# Requirement already satisfied: CacheControl==0.12.6 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 26)) (0.12.6)
# Requirement already satisfied: cachetools==4.1.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 27)) (4.1.0)
# Requirement already satisfied: catalogue==1.0.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 28)) (1.0.0)
# Requirement already satisfied: category-encoders==2.2.2 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 29)) (2.2.2)
# Requirement already satisfied: certifi==2020.4.5.2 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 30)) (2020.4.5.2)
# Requirement already satisfied: cffi==1.14.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 31)) (1.14.0)
# Requirement already satisfied: chainer==6.5.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 32)) (6.5.0)
# Requirement already satisfied: chardet==3.0.4 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 33)) (3.0.4)
# Requirement already satisfied: click==7.1.2 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 34)) (7.1.2)
# Requirement already satisfied: cloudpickle==1.3.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 35)) (1.3.0)
# Requirement already satisfied: cmake==3.12.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 36)) (3.12.0)
# Requirement already satisfied: cmdstanpy==0.4.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 37)) (0.4.0)
# Requirement already satisfied: colorlover==0.3.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 38)) (0.3.0)
# Requirement already satisfied: community==1.0.0b1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 39)) (1.0.0b1)
# Requirement already satisfied: contextlib2==0.5.5 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 40)) (0.5.5)
# Requirement already satisfied: convertdate==2.2.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 41)) (2.2.1)
# Requirement already satisfied: coverage==3.7.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 42)) (3.7.1)
# Requirement already satisfied: coveralls==0.5 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 43)) (0.5)
# Requirement already satisfied: crcmod==1.7 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 44)) (1.7)
# Requirement already satisfied: cufflinks==0.17.3 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 45)) (0.17.3)
# Requirement already satisfied: cvxopt==1.2.5 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 46)) (1.2.5)
# Requirement already satisfied: cvxpy==1.0.31 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 47)) (1.0.31)
# Requirement already satisfied: cycler==0.10.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 48)) (0.10.0)
# Requirement already satisfied: cymem==2.0.3 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 49)) (2.0.3)
# Requirement already satisfied: Cython==0.29.20 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 50)) (0.29.20)
# Requirement already satisfied: daft==0.0.4 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 51)) (0.0.4)
# Requirement already satisfied: dask==2.12.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 52)) (2.12.0)
# Requirement already satisfied: dataclasses==0.7 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 53)) (0.7)
# Requirement already satisfied: datascience==0.10.6 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 54)) (0.10.6)
# Requirement already satisfied: decorator==4.4.2 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 55)) (4.4.2)
# Requirement already satisfied: defusedxml==0.6.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 56)) (0.6.0)
# Requirement already satisfied: descartes==1.1.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 57)) (1.1.0)
# Requirement already satisfied: dill==0.3.2 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 58)) (0.3.2)
# Requirement already satisfied: distributed==1.25.3 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 59)) (1.25.3)
# Requirement already satisfied: Django==3.0.7 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 60)) (3.0.7)
# Requirement already satisfied: dlib==19.18.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 61)) (19.18.0)
# Requirement already satisfied: docopt==0.6.2 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 62)) (0.6.2)
# Requirement already satisfied: docutils==0.15.2 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 63)) (0.15.2)
# Requirement already satisfied: dopamine-rl==1.0.5 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 64)) (1.0.5)
# Requirement already satisfied: earthengine-api==0.1.226 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 65)) (0.1.226)
# Requirement already satisfied: easydict==1.9 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 66)) (1.9)
# Requirement already satisfied: ecos==2.0.7.post1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 67)) (2.0.7.post1)
# Requirement already satisfied: editdistance==0.5.3 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 68)) (0.5.3)
# Requirement already satisfied: en-core-web-sm==2.2.5 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 69)) (2.2.5)
# Requirement already satisfied: entrypoints==0.3 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 70)) (0.3)
# Requirement already satisfied: ephem==3.7.7.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 71)) (3.7.7.1)
# Requirement already satisfied: et-xmlfile==1.0.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 72)) (1.0.1)
# Requirement already satisfied: fa2==0.3.5 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 73)) (0.3.5)
# Requirement already satisfied: fancyimpute==0.4.3 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 74)) (0.4.3)
# Requirement already satisfied: fastai==1.0.61 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 75)) (1.0.61)
# Requirement already satisfied: fastdtw==0.3.4 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 76)) (0.3.4)
# Requirement already satisfied: fastprogress==0.2.3 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 77)) (0.2.3)
# Requirement already satisfied: fastrlock==0.5 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 78)) (0.5)
# Requirement already satisfied: fbprophet==0.6 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 79)) (0.6)
# Requirement already satisfied: feather-format==0.4.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 80)) (0.4.1)
# Requirement already satisfied: featuretools==0.4.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 81)) (0.4.1)
# Requirement already satisfied: filelock==3.0.12 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 82)) (3.0.12)
# Requirement already satisfied: firebase-admin==4.1.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 83)) (4.1.0)
# Requirement already satisfied: fix-yahoo-finance==0.0.22 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 84)) (0.0.22)
# Requirement already satisfied: Flask==1.1.2 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 85)) (1.1.2)
# Requirement already satisfied: folium==0.8.3 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 86)) (0.8.3)
# Requirement already satisfied: fsspec==0.7.4 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 87)) (0.7.4)
# Requirement already satisfied: future==0.16.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 88)) (0.16.0)
# Requirement already satisfied: gast==0.3.3 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 89)) (0.3.3)
# Requirement already satisfied: GDAL==2.2.2 in /usr/lib/python3/dist-packages (from -r requirements.txt (line 90)) (2.2.2)
# Requirement already satisfied: gdown==3.6.4 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 91)) (3.6.4)
# Requirement already satisfied: gensim==3.6.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 92)) (3.6.0)
# Requirement already satisfied: geographiclib==1.50 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 93)) (1.50)
# Requirement already satisfied: geopy==1.17.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 94)) (1.17.0)
# Requirement already satisfied: gin-config==0.3.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 95)) (0.3.0)
# Requirement already satisfied: glob2==0.7 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 96)) (0.7)
# Requirement already satisfied: google==2.0.3 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 97)) (2.0.3)
# Requirement already satisfied: google-api-core==1.16.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 98)) (1.16.0)
# Requirement already satisfied: google-api-python-client==1.7.12 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 99)) (1.7.12)
# Requirement already satisfied: google-auth==1.17.2 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 100)) (1.17.2)
# Requirement already satisfied: google-auth-httplib2==0.0.3 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 101)) (0.0.3)
# Requirement already satisfied: google-auth-oauthlib==0.4.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 102)) (0.4.1)
# Requirement already satisfied: google-cloud-bigquery==1.21.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 103)) (1.21.0)
# Requirement already satisfied: google-cloud-core==1.0.3 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 104)) (1.0.3)
# Requirement already satisfied: google-cloud-datastore==1.8.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 105)) (1.8.0)
# Requirement already satisfied: google-cloud-firestore==1.7.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 106)) (1.7.0)
# Requirement already satisfied: google-cloud-language==1.2.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 107)) (1.2.0)
# Requirement already satisfied: google-cloud-storage==1.18.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 108)) (1.18.1)
# Requirement already satisfied: google-cloud-translate==1.5.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 109)) (1.5.0)
# Requirement already satisfied: google-colab==1.0.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 110)) (1.0.0)
# Requirement already satisfied: google-pasta==0.2.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 111)) (0.2.0)
# Requirement already satisfied: google-resumable-media==0.4.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 112)) (0.4.1)
# Requirement already satisfied: googleapis-common-protos==1.52.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 113)) (1.52.0)
# Requirement already satisfied: googledrivedownloader==0.4 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 114)) (0.4)
# Requirement already satisfied: graphviz==0.10.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 115)) (0.10.1)
# Requirement already satisfied: grpcio==1.29.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 116)) (1.29.0)
# Requirement already satisfied: gspread==3.0.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 117)) (3.0.1)
# Requirement already satisfied: gspread-dataframe==3.0.7 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 118)) (3.0.7)
# Requirement already satisfied: gTTS==2.1.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 119)) (2.1.1)
# Requirement already satisfied: gTTS-token==1.1.3 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 120)) (1.1.3)
# Requirement already satisfied: gym==0.17.2 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 121)) (0.17.2)
# Requirement already satisfied: h5py==2.10.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 122)) (2.10.0)
# Requirement already satisfied: HeapDict==1.0.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 123)) (1.0.1)
# Requirement already satisfied: holidays==0.9.12 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 124)) (0.9.12)
# Requirement already satisfied: html5lib==1.0.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 125)) (1.0.1)
# Requirement already satisfied: httpimport==0.5.18 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 126)) (0.5.18)
# Requirement already satisfied: httplib2==0.17.4 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 127)) (0.17.4)
# Requirement already satisfied: httplib2shim==0.0.3 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 128)) (0.0.3)
# Requirement already satisfied: humanize==0.5.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 129)) (0.5.1)
# Requirement already satisfied: hyperopt==0.1.2 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 130)) (0.1.2)
# Requirement already satisfied: ideep4py==2.0.0.post3 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 131)) (2.0.0.post3)
# Requirement already satisfied: idna==2.9 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 132)) (2.9)
# Requirement already satisfied: image==1.5.32 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 133)) (1.5.32)
# Requirement already satisfied: imageio==2.4.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 134)) (2.4.1)
# Requirement already satisfied: imagesize==1.2.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 135)) (1.2.0)
# Requirement already satisfied: imbalanced-learn==0.4.3 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 136)) (0.4.3)
# Requirement already satisfied: imblearn==0.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 137)) (0.0)
# Requirement already satisfied: imgaug==0.2.9 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 138)) (0.2.9)
# Requirement already satisfied: importlib-metadata==1.6.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 139)) (1.6.1)
# Requirement already satisfied: imutils==0.5.3 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 140)) (0.5.3)
# Requirement already satisfied: inflect==2.1.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 141)) (2.1.0)
# Requirement already satisfied: intel-openmp==2020.0.133 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 142)) (2020.0.133)
# Requirement already satisfied: intervaltree==2.1.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 143)) (2.1.0)
# Requirement already satisfied: ipykernel==4.10.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 144)) (4.10.1)
# Requirement already satisfied: ipython==5.5.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 145)) (5.5.0)
# Requirement already satisfied: ipython-genutils==0.2.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 146)) (0.2.0)
# Requirement already satisfied: ipython-sql==0.3.9 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 147)) (0.3.9)
# Requirement already satisfied: ipywidgets==7.5.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 148)) (7.5.1)
# Requirement already satisfied: itsdangerous==1.1.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 149)) (1.1.0)
# Requirement already satisfied: jax==0.1.69 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 150)) (0.1.69)
# Requirement already satisfied: jaxlib==0.1.47 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 151)) (0.1.47)
# Requirement already satisfied: jdcal==1.4.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 152)) (1.4.1)
# Requirement already satisfied: jedi==0.17.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 153)) (0.17.0)
# Requirement already satisfied: jieba==0.42.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 154)) (0.42.1)
# Requirement already satisfied: Jinja2==2.11.2 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 155)) (2.11.2)
# Requirement already satisfied: jmespath==0.10.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 156)) (0.10.0)
# Requirement already satisfied: joblib==0.15.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 157)) (0.15.1)
# Requirement already satisfied: jpeg4py==0.1.4 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 158)) (0.1.4)
# Requirement already satisfied: jsonschema==2.6.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 159)) (2.6.0)
# Requirement already satisfied: jupyter==1.0.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 160)) (1.0.0)
# Requirement already satisfied: jupyter-client==5.3.4 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 161)) (5.3.4)
# Requirement already satisfied: jupyter-console==5.2.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 162)) (5.2.0)
# Requirement already satisfied: jupyter-core==4.6.3 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 163)) (4.6.3)
# Requirement already satisfied: kaggle==1.5.6 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 164)) (1.5.6)
# Requirement already satisfied: kapre==0.1.3.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 165)) (0.1.3.1)
# Requirement already satisfied: Keras==2.3.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 166)) (2.3.1)
# Requirement already satisfied: Keras-Applications==1.0.8 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 167)) (1.0.8)
# Requirement already satisfied: Keras-Preprocessing==1.1.2 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 168)) (1.1.2)
# Requirement already satisfied: keras-vis==0.4.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 169)) (0.4.1)
# Requirement already satisfied: kiwisolver==1.2.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 170)) (1.2.0)
# Requirement already satisfied: knnimpute==0.1.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 171)) (0.1.0)
# Requirement already satisfied: librosa==0.6.3 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 172)) (0.6.3)
# Requirement already satisfied: lightgbm==2.2.3 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 173)) (2.2.3)
# Requirement already satisfied: llvmlite==0.31.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 174)) (0.31.0)
# Requirement already satisfied: lmdb==0.98 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 175)) (0.98)
# Requirement already satisfied: lucid==0.3.8 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 176)) (0.3.8)
# Requirement already satisfied: LunarCalendar==0.0.9 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 177)) (0.0.9)
# Requirement already satisfied: lxml==4.2.6 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 178)) (4.2.6)
# Requirement already satisfied: Markdown==3.2.2 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 179)) (3.2.2)
# Requirement already satisfied: MarkupSafe==1.1.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 180)) (1.1.1)
# Requirement already satisfied: matplotlib==3.2.2 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 181)) (3.2.2)
# Requirement already satisfied: matplotlib-venn==0.11.5 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 182)) (0.11.5)
# Requirement already satisfied: missingno==0.4.2 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 183)) (0.4.2)
# Requirement already satisfied: mistune==0.8.4 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 184)) (0.8.4)
# Requirement already satisfied: mizani==0.6.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 185)) (0.6.0)
# Requirement already satisfied: mkl==2019.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 186)) (2019.0)
# Requirement already satisfied: mlxtend==0.17.2 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 187)) (0.17.2)
# Requirement already satisfied: more-itertools==8.4.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 188)) (8.4.0)
# Requirement already satisfied: moviepy==0.2.3.5 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 189)) (0.2.3.5)
# Requirement already satisfied: mpmath==1.1.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 190)) (1.1.0)
# Requirement already satisfied: msgpack==1.0.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 191)) (1.0.0)
# Requirement already satisfied: multiprocess==0.70.10 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 192)) (0.70.10)
# Requirement already satisfied: multitasking==0.0.9 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 193)) (0.0.9)
# Requirement already satisfied: murmurhash==1.0.2 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 194)) (1.0.2)
# Requirement already satisfied: music21==5.5.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 195)) (5.5.0)
# Requirement already satisfied: natsort==5.5.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 196)) (5.5.0)
# Requirement already satisfied: nbconvert==5.6.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 197)) (5.6.1)
# Requirement already satisfied: nbformat==5.0.7 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 198)) (5.0.7)
# Requirement already satisfied: networkx==2.4 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 199)) (2.4)
# Requirement already satisfied: nibabel==3.0.2 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 200)) (3.0.2)
# Requirement already satisfied: nltk==3.2.5 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 201)) (3.2.5)
# Requirement already satisfied: notebook==5.2.2 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 202)) (5.2.2)
# Requirement already satisfied: np-utils==0.5.12.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 203)) (0.5.12.1)
# Requirement already satisfied: numba==0.48.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 204)) (0.48.0)
# Requirement already satisfied: numexpr==2.7.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 205)) (2.7.1)
# Requirement already satisfied: numpy==1.18.5 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 206)) (1.18.5)
# Requirement already satisfied: nvidia-ml-py3==7.352.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 207)) (7.352.0)
# Requirement already satisfied: oauth2client==4.1.3 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 208)) (4.1.3)
# Requirement already satisfied: oauthlib==3.1.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 209)) (3.1.0)
# Requirement already satisfied: okgrade==0.4.3 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 210)) (0.4.3)
# Requirement already satisfied: opencv-contrib-python==4.1.2.30 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 211)) (4.1.2.30)
# Requirement already satisfied: opencv-python==4.1.2.30 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 212)) (4.1.2.30)
# Requirement already satisfied: openpyxl==2.5.9 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 213)) (2.5.9)
# Requirement already satisfied: opt-einsum==3.2.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 214)) (3.2.1)
# Requirement already satisfied: osqp==0.6.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 215)) (0.6.1)
# Requirement already satisfied: packaging==20.4 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 216)) (20.4)
# Requirement already satisfied: palettable==3.3.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 217)) (3.3.0)
# Requirement already satisfied: pandas==1.0.5 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 218)) (1.0.5)
# Requirement already satisfied: pandas-datareader==0.8.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 219)) (0.8.1)
# Requirement already satisfied: pandas-gbq==0.11.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 220)) (0.11.0)
# Requirement already satisfied: pandas-profiling==1.4.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 221)) (1.4.1)
# Requirement already satisfied: pandocfilters==1.4.2 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 222)) (1.4.2)
# Requirement already satisfied: parso==0.7.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 223)) (0.7.0)
# Requirement already satisfied: pathlib==1.0.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 224)) (1.0.1)
# Requirement already satisfied: patsy==0.5.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 225)) (0.5.1)
# Requirement already satisfied: pexpect==4.8.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 226)) (4.8.0)
# Requirement already satisfied: pickleshare==0.7.5 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 227)) (0.7.5)
# Requirement already satisfied: Pillow==7.0.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 228)) (7.0.0)
# Requirement already satisfied: pip-tools==4.5.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 229)) (4.5.1)
# Requirement already satisfied: plac==1.1.3 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 230)) (1.1.3)
# Requirement already satisfied: plotly==4.4.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 231)) (4.4.1)
# Requirement already satisfied: plotnine==0.6.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 232)) (0.6.0)
# Requirement already satisfied: pluggy==0.7.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 233)) (0.7.1)
# Requirement already satisfied: portpicker==1.3.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 234)) (1.3.1)
# Requirement already satisfied: ppscore==0.0.3 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 235)) (0.0.3)
# Requirement already satisfied: prefetch-generator==1.0.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 236)) (1.0.1)
# Requirement already satisfied: preshed==3.0.2 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 237)) (3.0.2)
# Requirement already satisfied: prettytable==0.7.2 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 238)) (0.7.2)
# Requirement already satisfied: progressbar2==3.38.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 239)) (3.38.0)
# Requirement already satisfied: prometheus-client==0.8.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 240)) (0.8.0)
# Requirement already satisfied: promise==2.3 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 241)) (2.3)
# Requirement already satisfied: prompt-toolkit==1.0.18 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 242)) (1.0.18)
# Requirement already satisfied: protobuf==3.10.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 243)) (3.10.0)
# Requirement already satisfied: psutil==5.4.8 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 244)) (5.4.8)
# Requirement already satisfied: psycopg2==2.7.6.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 245)) (2.7.6.1)
# Requirement already satisfied: ptyprocess==0.6.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 246)) (0.6.0)
# Requirement already satisfied: py==1.8.2 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 247)) (1.8.2)
# Requirement already satisfied: pyarrow==0.14.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 248)) (0.14.1)
# Requirement already satisfied: pyasn1==0.4.8 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 249)) (0.4.8)
# Requirement already satisfied: pyasn1-modules==0.2.8 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 250)) (0.2.8)
# Requirement already satisfied: pycocotools==2.0.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 251)) (2.0.1)
# Requirement already satisfied: pycparser==2.20 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 252)) (2.20)
# Requirement already satisfied: pydata-google-auth==1.1.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 253)) (1.1.0)
# Requirement already satisfied: pydot==1.3.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 254)) (1.3.0)
# Requirement already satisfied: pydot-ng==2.0.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 255)) (2.0.0)
# Requirement already satisfied: pydotplus==2.0.2 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 256)) (2.0.2)
# Requirement already satisfied: PyDrive==1.3.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 257)) (1.3.1)
# Requirement already satisfied: pyemd==0.5.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 258)) (0.5.1)
# Requirement already satisfied: pyglet==1.5.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 259)) (1.5.0)
# Requirement already satisfied: Pygments==2.1.3 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 260)) (2.1.3)
# Requirement already satisfied: pygobject==3.26.1 in /usr/lib/python3/dist-packages (from -r requirements.txt (line 261)) (3.26.1)
# Requirement already satisfied: pymc3==3.7 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 262)) (3.7)
# Requirement already satisfied: PyMeeus==0.3.7 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 263)) (0.3.7)
# Requirement already satisfied: pymongo==3.10.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 264)) (3.10.1)
# Requirement already satisfied: pymystem3==0.2.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 265)) (0.2.0)
# Requirement already satisfied: PyOpenGL==3.1.5 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 266)) (3.1.5)
# Requirement already satisfied: pyparsing==2.4.7 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 267)) (2.4.7)
# Requirement already satisfied: pyrsistent==0.16.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 268)) (0.16.0)
# Requirement already satisfied: pysndfile==1.3.8 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 269)) (1.3.8)
# Requirement already satisfied: PySocks==1.7.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 270)) (1.7.1)
# Requirement already satisfied: pystan==2.19.1.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 271)) (2.19.1.1)
# Requirement already satisfied: pytest==3.6.4 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 272)) (3.6.4)
# Requirement already satisfied: python-apt==1.6.5+ubuntu0.3 in /usr/lib/python3/dist-packages (from -r requirements.txt (line 273)) (1.6.5+ubuntu0.3)
# Requirement already satisfied: python-chess==0.23.11 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 274)) (0.23.11)
# Requirement already satisfied: python-dateutil==2.8.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 275)) (2.8.1)
# Requirement already satisfied: python-louvain==0.14 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 276)) (0.14)
# Requirement already satisfied: python-slugify==4.0.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 277)) (4.0.0)
# Requirement already satisfied: python-utils==2.4.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 278)) (2.4.0)
# Requirement already satisfied: pytz==2018.9 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 279)) (2018.9)
# Requirement already satisfied: PyWavelets==1.1.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 280)) (1.1.1)
# Requirement already satisfied: PyYAML==3.13 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 281)) (3.13)
# Requirement already satisfied: pyzmq==19.0.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 282)) (19.0.1)
# Requirement already satisfied: qtconsole==4.7.4 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 283)) (4.7.4)
# Requirement already satisfied: QtPy==1.9.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 284)) (1.9.0)
# Requirement already satisfied: regex==2019.12.20 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 285)) (2019.12.20)
# Requirement already satisfied: requests==2.23.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 286)) (2.23.0)
# Requirement already satisfied: requests-oauthlib==1.3.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 287)) (1.3.0)
# Requirement already satisfied: resampy==0.2.2 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 288)) (0.2.2)
# Requirement already satisfied: retrying==1.3.3 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 289)) (1.3.3)
# Requirement already satisfied: rpy2==3.2.7 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 290)) (3.2.7)
# Requirement already satisfied: rsa==4.6 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 291)) (4.6)
# Requirement already satisfied: s3fs==0.4.2 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 292)) (0.4.2)
# Requirement already satisfied: s3transfer==0.3.3 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 293)) (0.3.3)
# Requirement already satisfied: scikit-image==0.16.2 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 294)) (0.16.2)
# Requirement already satisfied: scikit-learn==0.23.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 295)) (0.23.1)
# Requirement already satisfied: scipy==1.4.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 296)) (1.4.1)
# Requirement already satisfied: screen-resolution-extra==0.0.0 in /usr/lib/python3/dist-packages (from -r requirements.txt (line 297)) (0.0.0)
# Requirement already satisfied: scs==2.1.2 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 298)) (2.1.2)
# Requirement already satisfied: seaborn==0.10.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 299)) (0.10.1)
# Requirement already satisfied: Send2Trash==1.5.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 300)) (1.5.0)
# Requirement already satisfied: setuptools-git==1.2 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 301)) (1.2)
# Requirement already satisfied: Shapely==1.7.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 302)) (1.7.0)
# Requirement already satisfied: simplegeneric==0.8.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 303)) (0.8.1)
# Requirement already satisfied: simplejson==3.17.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 304)) (3.17.0)
# Requirement already satisfied: six==1.12.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 305)) (1.12.0)
# Requirement already satisfied: sklearn==0.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 306)) (0.0)
# Requirement already satisfied: sklearn-pandas==1.8.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 307)) (1.8.0)
# Requirement already satisfied: smart-open==2.0.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 308)) (2.0.0)
# Requirement already satisfied: snowballstemmer==2.0.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 309)) (2.0.0)
# Requirement already satisfied: sortedcontainers==2.2.2 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 310)) (2.2.2)
# Requirement already satisfied: spacy==2.2.4 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 311)) (2.2.4)
# Requirement already satisfied: Sphinx==1.8.5 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 312)) (1.8.5)
# Requirement already satisfied: sphinxcontrib-websupport==1.2.2 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 313)) (1.2.2)
# Requirement already satisfied: SQLAlchemy==1.3.17 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 314)) (1.3.17)
# Requirement already satisfied: sqlparse==0.3.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 315)) (0.3.1)
# Requirement already satisfied: srsly==1.0.2 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 316)) (1.0.2)
# Requirement already satisfied: statsmodels==0.10.2 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 317)) (0.10.2)
# Requirement already satisfied: sympy==1.1.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 318)) (1.1.1)
# Requirement already satisfied: tables==3.4.4 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 319)) (3.4.4)
# Requirement already satisfied: tabulate==0.8.7 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 320)) (0.8.7)
# Requirement already satisfied: tbb==2020.0.133 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 321)) (2020.0.133)
# Requirement already satisfied: tblib==1.6.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 322)) (1.6.0)
# Requirement already satisfied: tensorboard==2.2.2 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 323)) (2.2.2)
# Requirement already satisfied: tensorboard-plugin-wit==1.6.0.post3 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 324)) (1.6.0.post3)
# Requirement already satisfied: tensorboardcolab==0.0.22 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 325)) (0.0.22)
# Requirement already satisfied: tensorflow==2.2.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 326)) (2.2.0)
# Requirement already satisfied: tensorflow-addons==0.8.3 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 327)) (0.8.3)
# Requirement already satisfied: tensorflow-datasets==2.1.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 328)) (2.1.0)
# Requirement already satisfied: tensorflow-estimator==2.2.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 329)) (2.2.0)
# Requirement already satisfied: tensorflow-gcs-config==2.1.8 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 330)) (2.1.8)
# Requirement already satisfied: tensorflow-hub==0.8.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 331)) (0.8.0)
# Requirement already satisfied: tensorflow-metadata==0.22.2 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 332)) (0.22.2)
# Requirement already satisfied: tensorflow-privacy==0.2.2 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 333)) (0.2.2)
# Requirement already satisfied: tensorflow-probability==0.10.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 334)) (0.10.0)
# Requirement already satisfied: termcolor==1.1.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 335)) (1.1.0)
# Requirement already satisfied: terminado==0.8.3 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 336)) (0.8.3)
# Requirement already satisfied: testpath==0.4.4 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 337)) (0.4.4)
# Requirement already satisfied: text-unidecode==1.3 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 338)) (1.3)
# Requirement already satisfied: textblob==0.15.3 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 339)) (0.15.3)
# Requirement already satisfied: textgenrnn==1.4.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 340)) (1.4.1)
# Requirement already satisfied: Theano==1.0.4 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 341)) (1.0.4)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 342)) (7.4.0)
# Requirement already satisfied: threadpoolctl==2.1.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 343)) (2.1.0)
# Requirement already satisfied: tifffile==2020.6.3 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 344)) (2020.6.3)
# Requirement already satisfied: toolz==0.10.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 345)) (0.10.0)
# Requirement already satisfied: torch==1.5.1+cu101 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 346)) (1.5.1+cu101)
# Requirement already satisfied: torchsummary==1.5.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 347)) (1.5.1)
# Requirement already satisfied: torchtext==0.3.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 348)) (0.3.1)
# Requirement already satisfied: torchvision==0.6.1+cu101 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 349)) (0.6.1+cu101)
# Requirement already satisfied: tornado==4.5.3 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 350)) (4.5.3)
# Requirement already satisfied: tqdm==4.41.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 351)) (4.41.1)
# Requirement already satisfied: traitlets==4.3.3 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 352)) (4.3.3)
# Requirement already satisfied: tweepy==3.6.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 353)) (3.6.0)
# Requirement already satisfied: typeguard==2.7.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 354)) (2.7.1)
# Requirement already satisfied: typing==3.6.6 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 355)) (3.6.6)
# Requirement already satisfied: typing-extensions==3.6.6 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 356)) (3.6.6)
# Requirement already satisfied: tzlocal==1.5.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 357)) (1.5.1)
# Requirement already satisfied: umap-learn==0.4.4 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 358)) (0.4.4)
# Requirement already satisfied: uritemplate==3.0.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 359)) (3.0.1)
# Requirement already satisfied: urllib3==1.24.3 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 360)) (1.24.3)
# Requirement already satisfied: vega-datasets==0.8.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 361)) (0.8.0)
# Requirement already satisfied: wasabi==0.6.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 362)) (0.6.0)
# Requirement already satisfied: wcwidth==0.2.4 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 363)) (0.2.4)
# Requirement already satisfied: webencodings==0.5.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 364)) (0.5.1)
# Requirement already satisfied: Werkzeug==1.0.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 365)) (1.0.1)
# Requirement already satisfied: widgetsnbextension==3.5.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 366)) (3.5.1)
# Requirement already satisfied: wordcloud==1.5.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 367)) (1.5.0)
# Requirement already satisfied: wrapt==1.12.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 368)) (1.12.1)
# Requirement already satisfied: xarray==0.15.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 369)) (0.15.1)
# Requirement already satisfied: xgboost==0.90 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 370)) (0.90)
# Requirement already satisfied: xkit==0.0.0 in /usr/lib/python3/dist-packages (from -r requirements.txt (line 371)) (0.0.0)
# Requirement already satisfied: xlrd==1.1.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 372)) (1.1.0)
# Requirement already satisfied: xlwt==1.3.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 373)) (1.3.0)
# Requirement already satisfied: yellowbrick==0.9.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 374)) (0.9.1)
# Requirement already satisfied: zict==2.0.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 375)) (2.0.0)
# Requirement already satisfied: zipp==3.1.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 376)) (3.1.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.6/dist-packages (from astunparse==1.6.3->-r requirements.txt (line 8)) (0.34.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from chainer==6.5.0->-r requirements.txt (line 32)) (47.3.1)

# %%
from P4_functions import *
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.decomposition.pca module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.decomposition. Anything that cannot be imported from sklearn.decomposition is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %% [markdown]
# Importation of modules and packages.

# %%
import io
# import re
import simplejson as json
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.facecolor']='w'
# from ipywidgets import interact, interact_manual
import warnings
warnings.filterwarnings('ignore')

import missingno as msno
import ppscore as pps

import dill

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from mlxtend.plotting import plot_pca_correlation_graph

import category_encoders as ce

from sklearn.pipeline import Pipeline
from sklearn.model_selection import KFold, GridSearchCV, train_test_split, StratifiedShuffleSplit
from sklearn.linear_model import *
from sklearn import metrics

# %% [markdown]
# Setting pandas display options

# %%
dictPdSettings = {'display.max_rows': 500, 'display.width': 100,
                    'display.max_colwidth': 100,
                    'display.float_format': lambda x: '%.2f' % x}
for k,v in dictPdSettings.items():
  pd.set_option(k,v)

# %% [markdown]
# To play audio text-to-speech during execution.

# %%
from IPython.display import Audio
from gtts import gTTS

def speak(text, lang='en'):
    with io.BytesIO() as f:
        gTTS(text=text, lang=lang).write_to_fp(f)
        f.seek(0)
        return Audio(f.read(), autoplay=True)

# %%
plot_enabled = False
save_enabled = False

# %%
speak('Packages and modules successfully imported')
# Out:
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### 0.1 Importing the dataset

# %%
if is_colab==True:
    path_csv_1 = 'DATA/2015-building-energy-benchmarking.csv' 
    path_csv_2 = 'DATA/2016-building-energy-benchmarking.csv'
    path_json_1 = 'DATA/datasets_34249_1051576_socrata_metadata_2015-building-energy-benchmarking.json'
    path_json_2 = 'DATA/datasets_34249_1051576_socrata_metadata_2016-building-energy-benchmarking.json'
    # Importing database from my Drive
    print("2. Try to import in notebook from myDrive...")
else:
    path_csv_1 = '../DATA/2015-building-energy-benchmarking.csv'
    path_csv_2 = '../DATA/2016-building-energy-benchmarking.csv'
    # Importing database from a DATA directory
    print("2. Try to import in notebook from PC ('DATA')")

df_2015 = pd.read_csv(path_csv_1, sep=',',
                 low_memory=True, encoding ='utf-8')
df_2016 = pd.read_csv(path_csv_2, sep=',',
                 low_memory=True, encoding ='utf-8')
# json_str_2015 = pd.read_csv(path_json_1, sep=',',
#                  low_memory=True, encoding ='utf-8')


print("-----> importation of .csv  and .jsonfiles in notebook OK")
# Out:
# 2. Try to import in notebook from myDrive...
# -----> importation of .csv  and .jsonfiles in notebook OK

# %% [markdown]
# Importing metadata in python dictionnary

# %%
json_dict_2015 = json.loads(open(path_json_1, "rt").read())
json_dict_2016 = json.loads(open(path_json_2, "rt").read())

# %%
# df_2015.info(memory_usage='deep')

# %%
# df_2016.info(memory_usage='deep')

# %%
speak('Datasets successfully imported')
# Out:
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### 0.2 First Overview
#
# First description of the data

# %%
# desc_2015 = df_2015.describe(include='all')
# desc_2015

# %%
# desc_2016 = df_2016.describe(include='all')
# desc_2016

# %% [markdown]
# Checking the columns

# %%
# for i, c in enumerate(df_2015.columns):
#     print('\n'+c if i % 3 == 0 else c, end=' | ')
# print('\n')
# for i, c in enumerate(df_2016.columns):
#     print('\n'+c if i % 3 == 0 else c, end=' | ')

# %% [markdown]
# Printing total nb and percentage of null

# %%
print_null_pct(df_2015)
print_null_pct(df_2016)
# Out:
# nb of null:  26512
# pct of null:  16.9
# nb of null:  19952
# pct of null:  12.8

# %% [markdown]
# Visualizing missing data for each dataframes

# %%
# plot_export_missing(df_2015, df_2015.columns, 'missing_vals_2015.png',
#                     'Overview of missing data in benchmarking_2015\n(before cleaning)',
#                     shorten_label=True)

# %%
# plot_export_missing(df_2016, df_2016.columns, 'missing_vals_2016.png',
#                     'Overview of missing data in benchmarking_2016\n(before cleaning)',
#                     shorten_label=True)

# %%
speak('Description overview done')
# Out:
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## 1 Data Cleaning

# %% [markdown]
# ### 1.1 Merging 2015 and 2016 data

# %% [markdown]
# #### Checking available columns
#
# Printing the list of the shared columns in df_2015 and df_2016, then only in df_2015 and then only in df_2016.

# %%
col_list = [c for c in df_2016.columns if c in df_2015.columns]
print("both in 2015 and 2016 ({}):".format(len(col_list)))
for i, c in enumerate(col_list,1):
    if i%6==1: print('')
    print(c, end=' | ')

col_list_2015 = [c for c in df_2015.columns if c not in df_2016.columns]
print("\n\nonly in 2015 ({}):".format(len(col_list_2015)))
for i, c in enumerate(col_list_2015,1):
    if i%6==1: print('')
    print(c, end=' | ')

col_list_2016 = [c for c in df_2016.columns if c not in df_2015.columns]
print("\n\nonly in 2016 ({}):".format(len(col_list_2016)))
for i, c in enumerate(col_list_2016,1):
    if i%6==1: print('')
    print(c, end=' | ')
# Out:
# both in 2015 and 2016 (37):
#
# OSEBuildingID | DataYear | BuildingType | PrimaryPropertyType | PropertyName | TaxParcelIdentificationNumber |
# CouncilDistrictCode | Neighborhood | YearBuilt | NumberofBuildings | NumberofFloors | PropertyGFATotal |
# PropertyGFAParking | PropertyGFABuilding(s) | ListOfAllPropertyUseTypes | LargestPropertyUseType | LargestPropertyUseTypeGFA | SecondLargestPropertyUseType |
# SecondLargestPropertyUseTypeGFA | ThirdLargestPropertyUseType | ThirdLargestPropertyUseTypeGFA | YearsENERGYSTARCertified | ENERGYSTARScore | SiteEUI(kBtu/sf) |
# SiteEUIWN(kBtu/sf) | SourceEUI(kBtu/sf) | SourceEUIWN(kBtu/sf) | SiteEnergyUse(kBtu) | SiteEnergyUseWN(kBtu) | SteamUse(kBtu) |
# Electricity(kWh) | Electricity(kBtu) | NaturalGas(therms) | NaturalGas(kBtu) | DefaultData | ComplianceStatus |
# Outlier |
#
# only in 2015 (10):
#
# Location | OtherFuelUse(kBtu) | GHGEmissions(MetricTonsCO2e) | GHGEmissionsIntensity(kgCO2e/ft2) | Comment | 2010 Census Tracts |
# Seattle Police Department Micro Community Policing Plan Areas | City Council Districts | SPD Beats | Zip Codes |
#
# only in 2016 (9):
#
# Address | City | State | ZipCode | Latitude | Longitude |
# Comments | TotalGHGEmissions | GHGEmissionsIntensity |

# %% [markdown]
# #### Checking the sum of the energy sub-columns.

# %%
sel_cols_2015 = ['SteamUse(kBtu)', 'Electricity(kBtu)', 'NaturalGas(kBtu)',
                 'OtherFuelUse(kBtu)']
sel_cols_2016 = ['SteamUse(kBtu)', 'Electricity(kBtu)', 'NaturalGas(kBtu)']

# %% [markdown]
# In 2015:

# %%
res_2015 = pd.concat([(df_2015[sel_cols_2015]==0).sum(),
           (df_2015[sel_cols_2015]!=0).sum(),
           (df_2015[sel_cols_2015].isna()).sum()], axis=1)
res_2015.columns = ['==0', '!=0', 'is NaN']
res_2015
# Out:
#                      ==0   !=0  is NaN
# SteamUse(kBtu)      3200   140      10
# Electricity(kBtu)      2  3338      10
# NaturalGas(kBtu)    1256  2084      10
# OtherFuelUse(kBtu)  3313    27      10

# %%
res_2015_1 = df_2015[sel_cols_2015].sum(axis=1)/df_2015['SiteEnergyUse(kBtu)']
res_2015_2 = df_2015[sel_cols_2016].sum(axis=1)/df_2015['SiteEnergyUse(kBtu)']
print(min(res_2015_1), max(res_2015_1))
print(min(res_2015_2), max(res_2015_2))
fig, axs = plt.subplots(1,2)
fig.set_size_inches(12,1)
sns.boxplot(res_2015_1, ax=axs[0])
axs[0].set_title("with 'OtherFuel'")
sns.boxplot(res_2015_2, ax=axs[1])
axs[1].set_title("without 'OtherFuel'")
plt.show()
# Out:
# 0.9999986306847124 1.314227760703153
# 0.6958013685145714 1.314227760703153

# %% [markdown]
# In 2016:

# %%
res_2016 = pd.concat([(df_2016[sel_cols_2016]==0).sum(),
           (df_2016[sel_cols_2016]!=0).sum(),
           (df_2016[sel_cols_2016].isna()).sum()], axis=1)
res_2016.columns = ['==0', '!=0', 'is NaN']
res_2016
# Out:
#                     ==0   !=0  is NaN
# SteamUse(kBtu)     3237   139       9
# Electricity(kBtu)    14  3362       9
# NaturalGas(kBtu)   1258  2118       9

# %%
sel_cols_2016 = ['SteamUse(kBtu)', 'Electricity(kBtu)', 'NaturalGas(kBtu)']
res_2016 = df_2016[sel_cols_2016].sum(axis=1)/df_2016['SiteEnergyUse(kBtu)']
print(min(res_2016), max(res_2016))
fig, ax = plt.subplots(1)
fig.set_size_inches(12,1)
sns.boxplot(res_2016, ax=ax)
plt.show()
# Out:
# -0.3367616358600123 inf

# %% [markdown]
# #### Dropping, renaming, creating to harmonize the dataframes
#
# Dropping useless columns missing in one of the two datasets

# %%
df_2015 = df_2015.drop(columns=['City Council Districts', 'SPD Beats',
        'Seattle Police Department Micro Community Policing Plan Areas',
        '2010 Census Tracts'])
df_2016 = df_2016.drop(columns=['City', 'State'])

# %% [markdown]
# Renaming the columns to harmonize 2015 and 2016 datasets.

# %%
rename_2015 = {'Comment': 'Comments', 'Zip Codes': 'ZipCode',
               'GHGEmissions(MetricTonsCO2e)': 'TotalGHGEmissions',
               'GHGEmissionsIntensity(kgCO2e/ft2)': 'GHGEmissionsIntensity'}
df_2015 = df_2015.rename(columns=rename_2015)

# %% [markdown]
# Splitting the 'location' column in the 2015 dataset to recreate 'Latitude', Longitude', 'Address' and 'ZipCode'.
#
# NB: the original 'Zip Codes' column in the 2015 dataset seem to contain wrong zipcode. We take the valid zipcode from the 'Location' column to get valid values that we put in a new ZipCode column.

# %%
df_2015['Latitude'] = df_2015['Location'].apply(lambda x: eval(x)['latitude']).astype('float64')
df_2015['Longitude'] = df_2015['Location'].apply(lambda x: eval(x)['longitude']).astype('float64')
df_2015['HumanAddress'] = df_2015['Location'].apply(lambda x: eval(x)['human_address'])
df_2015['Address'] = df_2015['HumanAddress'].apply(lambda x: eval(x)['address'])
df_2015['ZipCode'] = df_2015['HumanAddress'].apply(lambda x: eval(x)['zip'])
df_2015 = df_2015.drop(columns=['Location', 'HumanAddress'])

# %% [markdown]
# Creating the missing column in 2016.

# %%
df_2016['OtherFuelUse(kBtu)'] = pd.Series([], dtype='float64')

# %% [markdown]
# Harmonizing the categories and the strings formatting.

# %%
df_2015['DefaultData'] = df_2015['DefaultData'].map({'No': False, 'Yes': True}).astype('bool')
df_2016['PropertyName'] = df_2016['PropertyName'].map(str.upper)

# %%
df_2015['DefaultData'].value_counts()
# Out:
# False    2791
# True      549
# Name: DefaultData, dtype: int64

# %% [markdown]
# #### Merging the dataframes
#
# Checking columns before we concatenate the two dataframes.

# %%
col_list = [c for c in df_2016.columns if c in df_2015.columns]
print("both in 2015 and 2016 ({}):".format(len(col_list)))
for i, c in enumerate(col_list,1):
    if i%6==1: print('')
    print(c, end=' | ')

col_list_2015 = [c for c in df_2015.columns if c not in df_2016.columns]
print("\n\nonly in 2015 ({}):".format(len(col_list)))
for i, c in enumerate(col_list_2015,1):
    if i%6==1: print('')
    print(c, end=' | ')

col_list_2016 = [c for c in df_2016.columns if c not in df_2015.columns]
print("\n\nonly in 2016 ({}):".format(len(col_list)))
for i, c in enumerate(col_list_2016,1):
    if i%6==1: print('')
    print(c, end=' | ')
# Out:
# both in 2015 and 2016 (45):
#
# OSEBuildingID | DataYear | BuildingType | PrimaryPropertyType | PropertyName | Address |
# ZipCode | TaxParcelIdentificationNumber | CouncilDistrictCode | Neighborhood | Latitude | Longitude |
# YearBuilt | NumberofBuildings | NumberofFloors | PropertyGFATotal | PropertyGFAParking | PropertyGFABuilding(s) |
# ListOfAllPropertyUseTypes | LargestPropertyUseType | LargestPropertyUseTypeGFA | SecondLargestPropertyUseType | SecondLargestPropertyUseTypeGFA | ThirdLargestPropertyUseType |
# ThirdLargestPropertyUseTypeGFA | YearsENERGYSTARCertified | ENERGYSTARScore | SiteEUI(kBtu/sf) | SiteEUIWN(kBtu/sf) | SourceEUI(kBtu/sf) |
# SourceEUIWN(kBtu/sf) | SiteEnergyUse(kBtu) | SiteEnergyUseWN(kBtu) | SteamUse(kBtu) | Electricity(kWh) | Electricity(kBtu) |
# NaturalGas(therms) | NaturalGas(kBtu) | DefaultData | Comments | ComplianceStatus | Outlier |
# TotalGHGEmissions | GHGEmissionsIntensity | OtherFuelUse(kBtu) |
#
# only in 2015 (45):
#
#
# only in 2016 (45):

# %% [markdown]
# Creating a new dataframe with data of 2015 and 2016

# %%
df = pd.concat([df_2015, df_2016]).sort_values('OSEBuildingID')

# %%
df['DataYear'] = df['DataYear'].apply(str)

# %% [markdown]
# Visualizing missing data for the merged dataframe.

# %%
plot_export_missing(df, df.columns, 'missing_vals_2015_2016.png',
      'Overview of missing data in merged benchmarking_2015-2016',
                    shorten_label=True, save_enabled=False)

# %% [markdown]
# ### 1.2 Dealing with formats

# %% [markdown]
# Changing list columns from strings to tuples:
#
# - 'YearsENERGYSTARCertified'

# %%
def split_dates(dates):
    dates_str = str(dates).replace('nan', '')
    if ',' in dates_str:
        ls_date = [s.strip() for s in str(dates_str).split(',')]
    else:
        if len(dates_str)%4==0:
            ls_date = [dates_str[4*(i):4*(i+1)] for i in range(int(len(dates_str)/4))]
        else:
            print("ERROR: ", dates_str)
    return tuple(ls_date)


df['YearsENERGYSTARCertified'] = df['YearsENERGYSTARCertified']\
                                             .apply(lambda x: split_dates(x))

# %% [markdown]
# - 'ListOfAllPropertyUseTypes'

# %%
df['ListOfAllPropertyUseTypes'] = df['ListOfAllPropertyUseTypes']\
                                    .apply(lambda x: tuple(str(x).split(',')))

# %% [markdown]
# Harmonizing categories for 'ComplianceStatus' column

# %%
df['ComplianceStatus'] = df['ComplianceStatus']\
                                      .replace('Non-Compliant','Not Compliant')

# %%
df.shape, df.columns
# Out:
# ((6716, 45),
#  Index(['OSEBuildingID', 'DataYear', 'BuildingType', 'PrimaryPropertyType', 'PropertyName',
#         'TaxParcelIdentificationNumber', 'CouncilDistrictCode', 'Neighborhood', 'YearBuilt',
#         'NumberofBuildings', 'NumberofFloors', 'PropertyGFATotal', 'PropertyGFAParking',
#         'PropertyGFABuilding(s)', 'ListOfAllPropertyUseTypes', 'LargestPropertyUseType',
#         'LargestPropertyUseTypeGFA', 'SecondLargestPropertyUseType',
#         'SecondLargestPropertyUseTypeGFA', 'ThirdLargestPropertyUseType',
#         'ThirdLargestPropertyUseTypeGFA', 'YearsENERGYSTARCertified', 'ENERGYSTARScore',
#         'SiteEUI(kBtu/sf)', 'SiteEUIWN(kBtu/sf)', 'SourceEUI(kBtu/sf)', 'SourceEUIWN(kBtu/sf)',
#         'SiteEnergyUse(kBtu)', 'SiteEnergyUseWN(kBtu)', 'SteamUse(kBtu)', 'Electricity(kWh)',
#         'Electricity(kBtu)', 'NaturalGas(therms)', 'NaturalGas(kBtu)', 'OtherFuelUse(kBtu)',
#         'TotalGHGEmissions', 'GHGEmissionsIntensity', 'DefaultData', 'Comments', 'ComplianceStatus',
#         'Outlier', 'ZipCode', 'Latitude', 'Longitude', 'Address'],
#        dtype='object'))

# %% [markdown]
# Upper case for 'Neighborhood' and 'Address' columns.

# %%
sel_cols = ['PropertyName','Neighborhood' ,'Address']
df[sel_cols] = df[sel_cols].applymap(str.upper)

# %% [markdown]
# Stripping Tax number.

# %%
df['TaxParcelIdentificationNumber'] = \
                            df['TaxParcelIdentificationNumber'].str.lstrip("0")

# %% [markdown]
# Checking unique categories for all object columns

# %%
# for c in df.select_dtypes('object').columns:
#     print( "column {}: mixed ({}) 2015 ({}) 2016 ({}) categories"\
#           .format(c, df[c].nunique(),
#                   df_2015[c].nunique(), df_2016[c].nunique()))

# %% [markdown]
# Reindexing the merged dataframe.

# %%
df = df.reset_index(drop=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6716 entries, 0 to 6715
# Data columns (total 45 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   OSEBuildingID                    6716 non-null   int64
#  1   DataYear                         6716 non-null   object
#  2   BuildingType                     6716 non-null   object
#  3   PrimaryPropertyType              6716 non-null   object
#  4   PropertyName                     6716 non-null   object
#  5   TaxParcelIdentificationNumber    6714 non-null   object
#  6   CouncilDistrictCode              6716 non-null   int64
#  7   Neighborhood                     6716 non-null   object
#  8   YearBuilt                        6716 non-null   int64
#  9   NumberofBuildings                6708 non-null   float64
#  10  NumberofFloors                   6708 non-null   float64
#  11  PropertyGFATotal                 6716 non-null   int64
#  12  PropertyGFAParking               6716 non-null   int64
#  13  PropertyGFABuilding(s)           6716 non-null   int64
#  14  ListOfAllPropertyUseTypes        6716 non-null   object
#  15  LargestPropertyUseType           6560 non-null   object
#  16  LargestPropertyUseTypeGFA        6560 non-null   float64
#  17  SecondLargestPropertyUseType     3238 non-null   object
#  18  SecondLargestPropertyUseTypeGFA  3238 non-null   float64
#  19  ThirdLargestPropertyUseType      1156 non-null   object
#  20  ThirdLargestPropertyUseTypeGFA   1156 non-null   float64
#  21  YearsENERGYSTARCertified         6716 non-null   object
#  22  ENERGYSTARScore                  5093 non-null   float64
#  23  SiteEUI(kBtu/sf)                 6699 non-null   float64
#  24  SiteEUIWN(kBtu/sf)               6700 non-null   float64
#  25  SourceEUI(kBtu/sf)               6697 non-null   float64
#  26  SourceEUIWN(kBtu/sf)             6697 non-null   float64
#  27  SiteEnergyUse(kBtu)              6701 non-null   float64
#  28  SiteEnergyUseWN(kBtu)            6700 non-null   float64
#  29  SteamUse(kBtu)                   6697 non-null   float64
#  30  Electricity(kWh)                 6697 non-null   float64
#  31  Electricity(kBtu)                6697 non-null   float64
#  32  NaturalGas(therms)               6697 non-null   float64
#  33  NaturalGas(kBtu)                 6697 non-null   float64
#  34  OtherFuelUse(kBtu)               3330 non-null   float64
#  35  TotalGHGEmissions                6697 non-null   float64
#  36  GHGEmissionsIntensity            6697 non-null   float64
#  37  DefaultData                      6716 non-null   bool
#  38  Comments                         13 non-null     object
#  39  ComplianceStatus                 6716 non-null   object
#  40  Outlier                          116 non-null    object
#  41  ZipCode                          6700 non-null   object
#  42  Latitude                         6716 non-null   float64
#  43  Longitude                        6716 non-null   float64
#  44  Address                          6716 non-null   object
# dtypes: bool(1), float64(22), int64(6), object(16)
# memory usage: 2.3+ MB

# %% [markdown]
# ### 1.2 Filtering data

# %% [markdown]
# #### Excluding residential housing
#
# We only want to keep non-residential data.

# %%
df['BuildingType'].unique()
# Out:
# array(['NonResidential', 'Nonresidential COS', 'Multifamily MR (5-9)',
#        'SPS-District K-12', 'Campus', 'Multifamily LR (1-4)',
#        'Multifamily HR (10+)', 'Nonresidential WA'], dtype=object)

# %% [markdown]
# We exclude Multifamily MR (5-9)', Multifamily LR (1-4)', 'Multifamily HR (10+)'

# %%
print("shape before: ", df.shape)
df = df[df['BuildingType'].isin(['NonResidential', 'Nonresidential COS', 
       'SPS-District K-12', 'Campus', 'Nonresidential WA'])]
print("shape after: ", df.shape)
# Out:
# shape before:  (6716, 45)
# shape after:  (3318, 45)

# %% [markdown]
# #### Excluding duplicated buildings (2015 or 2016 only)
#
# We exclude duplicated buildings as we want to be sure that the training set and the test set contain different buildings.
#
# We choose to keep among the duplicates the one with fewest NaN among a selection of crucial columns. For duplicates with the same number of NaN, we keep data with larger value of 'SiteEnergyUse(kBtu)'.

# %%
sel_cols = ['BuildingType', 'PrimaryPropertyType', 'NumberofBuildings',
            'NumberofFloors', 'PropertyGFATotal', 'PropertyGFAParking',
            'PropertyGFABuilding(s)', 'LargestPropertyUseType',
            'LargestPropertyUseTypeGFA', 'OSEBuildingID',
            'SiteEnergyUse(kBtu)'] # seleciton of crucial data

df_dup = df.loc[df.duplicated(subset=['OSEBuildingID'], keep=False),
                sel_cols].sort_values('OSEBuildingID').reset_index()

gb = df_dup.groupby('OSEBuildingID')[['SiteEnergyUse(kBtu)', 'index']]
mask = gb.agg({'SiteEnergyUse(kBtu)': lambda x: bool(np.argmax(x)),
               'index': lambda x: tuple(x.values)})

ind_to_drop = []
for oseid in mask.index: # keep the one with less nan
    first = mask.loc[oseid, 'index'][0]
    second = mask.loc[oseid, 'index'][1]
    if df.loc[first, sel_cols].notna().sum()<df.loc[second,
                                                    sel_cols].notna().sum():
        ind_to_drop.append(first) # keep second
    elif df.loc[first, sel_cols].notna().sum()>df.loc[second,
                                                      sel_cols].notna().sum():
        ind_to_drop.append(second) # keep first
    else: # case where nb of nan is the same
        if mask.loc[oseid,'SiteEnergyUse(kBtu)']: # True: keep the second
            ind_to_drop.append(first)
        else: # False: keep the first
            ind_to_drop.append(second)

df = df.drop(index=ind_to_drop)
print("shape after: ", df.shape)
# Out:
# shape after:  (1698, 45)

# %% [markdown]
# #### Checking coherency of 'Energy sub-columns' vs. 'SiteEnergyUse'
#
# At first we drop the rows where 'SiteEnergyUse(kBtu)' is 0.

# %%
df = df.dropna(subset=['SiteEnergyUse(kBtu)'])
df = df.drop(index=df[df['SiteEnergyUse(kBtu)']==0].index)
print("shape after: ", df.shape)
# Out:
# shape after:  (1696, 45)

# %% [markdown]
# We check that the column 'SiteEnergyUse(kBtu)' is the sum of the energy columns in (kBtu).

# %%
sub_energy_cols = ['SteamUse(kBtu)','Electricity(kBtu)',
                   'NaturalGas(kBtu)','OtherFuelUse(kBtu)']
df['SiteEnergyUse(kBtu)_calc'] = df[sub_energy_cols].sum(axis='columns')
m_en_out = ~df['SiteEnergyUse(kBtu)_calc'].between(df['SiteEnergyUse(kBtu)']*0.9,
                                                  df['SiteEnergyUse(kBtu)']*1.1)
print("Rows where the total energy is not\n \
in [90%-110%] range of the 'SiteEnergyUse(kBtu)': ",
df[m_en_out].shape[0], '/', df.shape[0])
# Out:
# Rows where the total energy is not
#  in [90%-110%] range of the 'SiteEnergyUse(kBtu)':  10 / 1696

# %% [markdown]
# We drop the rows when 'SiteEnergyUse(kBtu)' is not in 90% to 110% of the calculated value.
# When it is inside the is not in [90%-110%] interval, we nevertheless adjust the value of 'SiteEnergyUse(kBtu)' to the calculated value.

# %%
df = df.drop(index=df[m_en_out].index)
df['SiteEnergyUse(kBtu)'] = df['SiteEnergyUse(kBtu)_calc']
del df['SiteEnergyUse(kBtu)_calc']
print("shape after: ", df.shape)
# Out:
# shape after:  (1686, 45)

# %% [markdown]
# #### Checking coherency of 'GFA sub-columns' vs. 'PropertyGFATotal'
#
# Checking that the column 'PropertyGFATotal' is the sum of the sub GFA columns.
#
# Ther is two subsets of columns that are supposed to represent the totality of the area:
# - parking area or building area
# - three largest property use GFA

# %%
sub_GFA_cols1 = ['PropertyGFAParking', 'PropertyGFABuilding(s)']
sub_GFA_cols2 = ['LargestPropertyUseTypeGFA', 'SecondLargestPropertyUseTypeGFA',
       'ThirdLargestPropertyUseTypeGFA']

# %%
df['PropertyGFATotal_calc'] = df[sub_GFA_cols1].sum(axis='columns')
m_GFA_out = ~df['PropertyGFATotal_calc'].between(df['PropertyGFATotal']*0.99,
                                                  df['PropertyGFATotal']*1.01)
print("Rows where the total GFA is not\n \
in [99%-101%] range of the 'PropertyGFATotal': ",
df[m_GFA_out].shape[0], '/', df.shape[0])

# df = df.drop(index=df[m_GFA_out].index)
# df['PropertyGFATotal'] = df['PropertyGFATotal_calc']
# del df['PropertyGFATotal_calc']
# Out:
# Rows where the total GFA is not
#  in [99%-101%] range of the 'PropertyGFATotal':  0 / 1686

# %% [markdown]
# The total GFA is very precisely the sum of the parking area and the building area.

# %%
df['PropertyGFATotal_calc'] = df[sub_GFA_cols2].sum(axis='columns')
m_GFA_out = df['PropertyGFATotal_calc'].dropna().between(df['PropertyGFATotal']*1.000000000001,
                                                  df['PropertyGFATotal']*6)
print("Rows where the total GFA is not\n \
in [100%-700%] range of the 'PropertyGFATotal': ",
df[m_GFA_out].shape[0], '/', df.shape[0])

# df = df.drop(index=df[m_GFA_out].index)
# df['PropertyGFATotal'] = df['PropertyGFATotal_calc']
# del df['PropertyGFATotal_calc']

# 412 : entre 1 et 7
# Out:
# Rows where the total GFA is not
#  in [100%-700%] range of the 'PropertyGFATotal':  411 / 1686

# %% [markdown]
# Whereas the sum of the GFA use types are sometimes less than 1 or can reach 7...

# %%
speak('filtering of data: done')
# Out:
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### 1.3 Imputation of missing data

# %% [markdown]
# Columns can be split in three categories:
# - **unused data**: too precise id data
# - **properties**: not directly linked to CO2 emission metrics, thus can be used for the model without fearing data leakage. Some are quantitative, others are categorical and will have to be encoded.
# - **energy performance metrics**: data related with the metrics we want to calculate with our model, thus should not be used as input data for the model. However we can extract useful data from these.

# %%
id_cols = ['OSEBuildingID', 'TaxParcelIdentificationNumber',
               'CouncilDistrictCode', 'Neighborhood',
               'ListOfAllPropertyUseTypes'] # redondante ?

prop_cols = ['BuildingType', 'PrimaryPropertyType',
            'NumberofBuildings', 'NumberofFloors', 'PropertyGFATotal',
            'PropertyGFAParking','PropertyGFABuilding(s)',
            'LargestPropertyUseType', 'LargestPropertyUseTypeGFA',
            'SecondLargestPropertyUseType', 'SecondLargestPropertyUseTypeGFA',
            'ThirdLargestPropertyUseType', 'ThirdLargestPropertyUseTypeGFA']

prop_C_cols = list(df[prop_cols].select_dtypes('object').columns) # to encode
prop_Q_cols = list(df[prop_cols].select_dtypes(np.number).columns)

en_perf_metrics_cols = ['ENERGYSTARScore',
                        'SiteEUI(kBtu/sf)',
                        'SiteEUIWN(kBtu/sf)', 'SourceEUI(kBtu/sf)',
                        'SourceEUIWN(kBtu/sf)','SiteEnergyUse(kBtu)'
                        'SiteEnergyUseWN(kBtu)', 'SteamUse(kBtu)',
                        'Electricity(kWh)','Electricity(kBtu)',
                        'NaturalGas(therms)', 'NaturalGas(kBtu)',
                        'OtherFuelUse(kBtu)', 'TotalGHGEmissions',
                        'GHGEmissionsIntensity']

# %%
# plot_export_missing(df, prop_Q_cols, 'missing_vals_quant_2015_2016.png',
#                     'Overview of missing \nquantitative data',
#                     figsize=(4,8),shorten_label=True, save_enabled=False)

# %%
# plot_export_missing(df, prop_C_cols, 'missing_vals_categ_2015_2016.png',
#                     'Overview of missing \ncategorical data',
#                     figsize=(3,8),shorten_label=True, save_enabled=False)

# %%
for c in prop_cols+['SteamUse(kBtu)','Electricity(kBtu)','NaturalGas(therms)',
   'NaturalGas(kBtu)','OtherFuelUse(kBtu)']+['YearBuilt']:
    n = df[c].isna().sum()
    if n>0:
        print('o--',c, ': ',str(n)," MISSING VALUES !")
    else:
        print(c, "no missing values.")
# Out:
# BuildingType no missing values.
# PrimaryPropertyType no missing values.
# NumberofBuildings no missing values.
# NumberofFloors no missing values.
# PropertyGFATotal no missing values.
# PropertyGFAParking no missing values.
# PropertyGFABuilding(s) no missing values.
# o-- LargestPropertyUseType :  12  MISSING VALUES !
# o-- LargestPropertyUseTypeGFA :  12  MISSING VALUES !
# o-- SecondLargestPropertyUseType :  828  MISSING VALUES !
# o-- SecondLargestPropertyUseTypeGFA :  828  MISSING VALUES !
# o-- ThirdLargestPropertyUseType :  1335  MISSING VALUES !
# o-- ThirdLargestPropertyUseTypeGFA :  1335  MISSING VALUES !
# SteamUse(kBtu) no missing values.
# Electricity(kBtu) no missing values.
# NaturalGas(therms) no missing values.
# NaturalGas(kBtu) no missing values.
# o-- OtherFuelUse(kBtu) :  943  MISSING VALUES !
# YearBuilt no missing values.

# %% [markdown]
# Very few missing data except for:
# - quantitative: _'SecondLargestPropertyUseTypeGFA',  'ThirdLargestPropertyUseTypeGFA' and 'OtherFuelUse(kBtu)'_
# - categorical: 'SecondLargestPropertyUseType', 'ThirdLargestPropertyUseType'
#
# We'll impute :
# - quantitative data of energy in kBtu _('OtherFuelUse(kBtu)')_ to 0 if NaN
# - other data with less than 10% missing values _( 'LargestPropertyUseTypeGFA') and ('LargestPropertyUseType')_ will be imputed using knn imputer, (we'll use completely filled data to train the knn).
#
# - the data with more than 50% missing data
# _('SecondLargestPropertyUseTypeGFA', 'ThirdLargestPropertyUseTypeGFA', ''OtherFuelUse(kBtu)')_ and _('SecondLargestPropertyUseType', 'ThirdLargestPropertyUseType')_ will be set to 0 or to 'None' as it probably simply means that there is no Second or Third largest Proporty Use at all.

# %% [markdown]
# #### Case 'optional' missing data: setting to 0 or 'None'

# %%
for c in ['SecondLargestPropertyUseTypeGFA', 'ThirdLargestPropertyUseTypeGFA',
          'OtherFuelUse(kBtu)']:
    df[c] = df[c].fillna(0)
for c in ['SecondLargestPropertyUseType', 'ThirdLargestPropertyUseType']:
    df[c] = df[c].fillna('None')

# %% [markdown]
# #### Case missing data < 10%: KNN imputation

# %%
# var_model: to train | var_target: to impute

filled_cols = ['BuildingType', 'PrimaryPropertyType', 'NumberofBuildings',
               'NumberofFloors', 'PropertyGFATotal', 'PropertyGFAParking',
               'PropertyGFABuilding(s)']

# Automatic KNN classification
ind_to_impute, y_pr_ = knn_impute(df, var_model = filled_cols,
                                  var_target='LargestPropertyUseType',
                                    enc_strat_cat='label', plot=False)
print('Number of values to impute:', len(ind_to_impute))
df.loc[ind_to_impute, 'LargestPropertyUseType'] = y_pr_

# Automatic KNN regression
ind_to_impute, y_pr_ = knn_impute(df, var_model = filled_cols,#+['LargestPropertyUseType'],
                                  var_target='LargestPropertyUseTypeGFA',
                                    enc_strat_cat='label', plot=False)
print('Number of values to impute:', len(ind_to_impute))
df.loc[ind_to_impute, 'LargestPropertyUseTypeGFA'] = y_pr_
# Out:
# ooo----KNN CLASSIFICATION : LargestPropertyUseType
# --- model: f1=0.806, precision=0.806, recall=0.806
# --- dummy class. (stratified): f1=0.122, precision=0.122, recall=0.122
# --- dummy class. (most_frequent): f1=0.287, precision=0.287, recall=0.287
# --- dummy class. (uniform): f1=0.0119, precision=0.0119, recall=0.0119
# Number of values to impute: 12
# ooo----KNN REGRESSION : LargestPropertyUseTypeGFA
# --- model: 0.809
# --- normal random distribution: -0.408
# --- dummy regressor (mean) : r2_score=-0.000149
# --- dummy regressor (median) : r2_score=-0.113
# Number of values to impute: 12

# %%
speak('imputation of missing data: done')
# Out:
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### 1.4 Feature Engineering

# %% [markdown]
# #### Age of the building
#
# Deducing the building age or thedelay since the last major renovation (see metadata in json file) from building year and data year.

# %%
df['BuildingAge'] = df['DataYear'].astype(int)-df['YearBuilt']

# %% [markdown]
# #### Mean GFA per floor
#
# Deducing the mean GFA per floor from 'PropertyGFATotal' and 'NumberofFloors'.

# %%
df = df.drop(df[df['PropertyGFABuilding(s)']<0].index)

# %%
df['MeanGFAperFloor'] = df['PropertyGFABuilding(s)']/(df['NumberofFloors']+1)

# %% [markdown]
# #### Parking GFA ratio
#
# Deducing the surface of parkings ratio to the whole area.

# %%
df['ParkingGFARatio'] = df['PropertyGFAParking']/df['PropertyGFATotal']

# %% [markdown]
# #### Having the EnergySTAR certification or not
#
# From the column 'YearsENERGYSTARCertified', we can deduce:
# - if the building was certified during DataYear
# - if the building was certified the year prior to DataYear.
#
# Both could be used without data leakage as EnergySTAR only reflects energy efficiency of the buildings and not the actual energy consumption, however we take only 'CertifiedPreviousYear' as we may not know in advance if a building will be certified this year.

# %%
df['Certified'] = [False if t == () else d in t for d, t \
                   in df[['DataYear', 'YearsENERGYSTARCertified']].values]
df['CertifiedPreviousYear'] = [False if t == () else \
                               int(d)-1 in [int(d) for d in t] \
                               for d, t in df[['DataYear',
                                               'YearsENERGYSTARCertified']].values]

# %% [markdown]
# #### Number of years where EnergySTAR certification was obtained

# %%
df['NbYearsCertified'] = df['YearsENERGYSTARCertified'].apply(len)

# %% [markdown]
# #### Determining an energy consumption profile
#
# If we want to avoid data leakage, we'll avoid to take as any of the energy consumption (kBtu) data as parameters for our model, as energy consumption won't be available when we'll have to predict GHG Emissions.
# However, we could imagine building a consumption profile of the buildings based on the available equipment.
# For exemple, buildings with electrical heating apparatus are likely to use electricity as their main energy source throughout the year.
#
# We'll build a 'Profile' column based on precise consumption data columns, but we'll try to keep the categories wide enough to avoid data leakage.
#
# At first we calculate the proportion of SteamUse, Electricity, NaturalGas(therms), NaturalGas and OtherFuelUse and store the results in new columns.

# %%
sub_energy_ratio_cols = ['SteamUse(ratio)','Electricity(ratio)',
            'NaturalGas(ratio)','OtherFuelUse(ratio)']

for oc, nc in zip(sub_energy_cols, sub_energy_ratio_cols):
    df[nc] = df[oc]/df['SiteEnergyUse(kBtu)']

# %% [markdown]
# We plot the dispersion of these calculated ratio to have an idea of relevant boundaries for bining.

# %%
df[sub_energy_ratio_cols].hist(layout=(1,5))
plt.gcf().set_size_inches(12,3)

# %% [markdown]
# We will create new columns to have an overview of the energetic profile of the building.
#
# * _First option_: divide in 3 bins the consumption rate of each type of energy (steam 's', electricity 'e', gas 'g' and other 'o'), and aggregate the bins to make a profile.
#
#     for example:
#     - (0.67-1] steam, (0-0.33] gas, (0-0.33] electricity and (0-0.33] other -> S(geo)
#     - (0.33-0.67] steam, (0.33-0.67] electricity, (0-0.33] gas and (0-0.33] other -> se(go)
#     - (0.33-0.67] other, (0-0.33] electricity, (0-0.33] gas and (0-0.33] other -> o(seg)
#
# * _Second option_: a new column specifying the main energy source used.
#
#     for example: S, E, G, O for steam, electricity, natural gas or other.
#
#
# __First option__

# %%
sub_energy_bins_cols = ['SteamUse(bins)','Electricity(bins)',
            'NaturalGas(bins)','OtherFuelUse(bins)']

for oc, nc in zip(sub_energy_ratio_cols, sub_energy_bins_cols):
    df[nc] = pd.cut(df[oc], bins=[0,0.33,0.67,1],
                    labels=[f'({oc[0].lower()})', oc[0].lower(), oc[0]],
                    include_lowest=True)
    
df['EnergyProfile'] = df[sub_energy_bins_cols].apply(lambda x: ''.join(x),
                                                     axis=1)

# %% [markdown]
# Visualizing the count of rows for each profile.

# %%
df['EnergyProfile'].value_counts()
# Out:
# (s)E(n)(o)    892
# (s)en(o)      564
# (s)(e)N(o)    159
# se(n)(o)       47
# (s)e(n)(o)     15
# S(e)(n)(o)      3
# s(e)(n)(o)      3
# (s)(e)n(o)      2
# Name: EnergyProfile, dtype: int64

# %% [markdown]
# * __Second option__

# %%
df['MainEnergy'] = df[sub_energy_ratio_cols].apply(np.argmax, axis=1)
df['MainEnergy'] = df['MainEnergy'].map({0: 'Steam',
                                         1: 'Electricity',
                                         2: 'NaturalGas',
                                         3: 'OtherFuel'})

# %% [markdown]
# Adding the feature engineered columns to the list of available features to use in our model.

# %%
prop_cols += ['BuildingAge', 'MeanGFAperFloor', 'ParkingGFARatio',
              'CertifiedPreviousYear', 'EnergyProfile', 'MainEnergy',
              'NbYearsCertified']                                 
prop_Q_cols += ['BuildingAge', 'MeanGFAperFloor',
                'ParkingGFARatio', 'NbYearsCertified']
prop_C_cols += ['CertifiedPreviousYear', 'EnergyProfile', 'MainEnergy']

# %%
speak('feature engineering: done')
# Out:
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## 2 Data exploration

# %% [markdown]
# #### Describe

# %%
df[prop_cols].describe(include='all')
# Out:
#           BuildingType  ... NbYearsCertified
# count             1685  ...          1685.00
# unique               5  ...              nan
# top     NonResidential  ...              nan
# freq              1479  ...              nan
# mean               NaN  ...             0.20
# std                NaN  ...             1.02
# min                NaN  ...             0.00
# 25%                NaN  ...             0.00
# 50%                NaN  ...             0.00
# 75%                NaN  ...             0.00
# max                NaN  ...            15.00
#
# [11 rows x 20 columns]

# %% [markdown]
# ### 2.1 Quantitative data

# %% [markdown]
# #### Boxplots

# %%
fig, axs = plt.subplots(len(df[prop_Q_cols].columns),1,
                        figsize=(8, 12), sharey=False)
for c, ax in zip(df[prop_Q_cols].columns, axs):
    df.boxplot(c, vert=False, ax=ax)
fig.tight_layout(h_pad=0.051)
if save_enabled: plt.savefig(os.getcwd()+'/FIG/'+'2_1_boxplots.png',
                             dpi=400);
plt.show()

# %% [markdown]
# #### Histograms
#
# Plotting histograms of the main quantitative continuous columns.

# %%
plot_histograms(df=df, cols=prop_Q_cols, file_name='2_1_histograms.png',
                figsize=(12,12), layout=(5,3), save_enabled=save_enabled)

# %% [markdown]
# QQ plots and normality tests

# %%
for i, c in enumerate(df[prop_Q_cols].columns,1):
    plot_hist_qqplot(df[c].dropna().values, c, save=False)
    plt.show()
    with pd.option_context('display.float_format', '{:,.3f}'.format):
        display(normality_tests(df[c], print_opt=False))
# Out:
#                       stat  ...                                                             res
# Shapiro-Wilk         0.080  ...                                                           False
# D'Agostino K^2   3,563.443  ...                                                           False
# Anderson-Darling   591.789  ...  [(15, False), (10, False), (5, False), (2, False), (1, False)]
#
# [3 rows x 3 columns]
#                       stat  ...                                                             res
# Shapiro-Wilk         0.444  ...                                                           False
# D'Agostino K^2   1,980.867  ...                                                           False
# Anderson-Darling   264.219  ...  [(15, False), (10, False), (5, False), (2, False), (1, False)]
#
# [3 rows x 3 columns]
#                       stat  ...                                                             res
# Shapiro-Wilk         0.471  ...                                                           False
# D'Agostino K^2   1,706.523  ...                                                           False
# Anderson-Darling   269.969  ...  [(15, False), (10, False), (5, False), (2, False), (1, False)]
#
# [3 rows x 3 columns]
#                       stat  ...                                                             res
# Shapiro-Wilk         0.341  ...                                                           False
# D'Agostino K^2   1,773.957  ...                                                           False
# Anderson-Darling   430.772  ...  [(15, False), (10, False), (5, False), (2, False), (1, False)]
#
# [3 rows x 3 columns]
#                       stat  ...                                                             res
# Shapiro-Wilk         0.451  ...                                                           False
# D'Agostino K^2   1,816.961  ...                                                           False
# Anderson-Darling   277.100  ...  [(15, False), (10, False), (5, False), (2, False), (1, False)]
#
# [3 rows x 3 columns]
#                       stat  ...                                                             res
# Shapiro-Wilk         0.468  ...                                                           False
# D'Agostino K^2   1,750.174  ...                                                           False
# Anderson-Darling   266.910  ...  [(15, False), (10, False), (5, False), (2, False), (1, False)]
#
# [3 rows x 3 columns]
#                       stat  ...                                                             res
# Shapiro-Wilk         0.386  ...                                                           False
# D'Agostino K^2   1,872.102  ...                                                           False
# Anderson-Darling   350.876  ...  [(15, False), (10, False), (5, False), (2, False), (1, False)]
#
# [3 rows x 3 columns]
#                       stat  ...                                                             res
# Shapiro-Wilk         0.149  ...                                                           False
# D'Agostino K^2   3,368.496  ...                                                           False
# Anderson-Darling   488.274  ...  [(15, False), (10, False), (5, False), (2, False), (1, False)]
#
# [3 rows x 3 columns]
#                     stat  ...                                                             res
# Shapiro-Wilk       0.949  ...                                                           False
# D'Agostino K^2   530.580  ...                                                           False
# Anderson-Darling  23.342  ...  [(15, False), (10, False), (5, False), (2, False), (1, False)]
#
# [3 rows x 3 columns]
#                       stat  ...                                                             res
# Shapiro-Wilk         0.287  ...                                                           False
# D'Agostino K^2   2,878.990  ...                                                           False
# Anderson-Darling   324.341  ...  [(15, False), (10, False), (5, False), (2, False), (1, False)]
#
# [3 rows x 3 columns]
#                     stat  ...                                                             res
# Shapiro-Wilk       0.516  ...                                                           False
# D'Agostino K^2   814.305  ...                                                           False
# Anderson-Darling 381.241  ...  [(15, False), (10, False), (5, False), (2, False), (1, False)]
#
# [3 rows x 3 columns]
#                       stat  ...                                                             res
# Shapiro-Wilk         0.194  ...                                                           False
# D'Agostino K^2   2,214.720  ...                                                           False
# Anderson-Darling   561.430  ...  [(15, False), (10, False), (5, False), (2, False), (1, False)]
#
# [3 rows x 3 columns]

# %% [markdown]
# None of the quantitative data have normal distribution.

# %% [markdown]
# #### Correlations

# %%
# Linear correlation (Pearson)

pears_corr = df[prop_Q_cols].corr()
plot_heatmap(pears_corr, shape='tri',
             title="Pearson correlation", figsize=(12,5))
if save_enabled: plt.savefig(os.getcwd()+'/FIG/'+'2_1_pearson.png',
                             dpi=400);
plt.show()

# %%
# Correlation test

test_couples = [('PropertyGFATotal','PropertyGFABuilding(s)'),
                ('PropertyGFATotal','LargestPropertyUseTypeGFA'),
                ('PropertyGFATotal','NumberofFloors'),
                ('PropertyGFATotal','PropertyGFAParking'),
                ('ParkingGFARatio','PropertyGFAParking'),
                ('NumberofFloors','LargestPropertyUseTypeGFA'),
                ('MeanGFAperFloor','PropertyGFABuilding(s)'),
                ('SecondLargestPropertyUseTypeGFA','ThirdLargestPropertyUseTypeGFA'),
                ('NumberofFloors','PropertyGFABuilding(s)'),
                ('ParkingGFARatio','BuildingAge'),
                ('NumberofFloors','BuildingAge'),
                ('NumberofBuildings','NbYearsCertified')]

for tup in test_couples:
    print('------'+str(tup).upper()+'-----')
    c1, c2 = tup
    display(correlation_tests(df[c1], df[c2], print_opt=False))
del tup
# Out:
# ------('PROPERTYGFATOTAL', 'PROPERTYGFABUILDING(S)')-----
#           stat  p_value
# Pearson   0.98     0.00
# Spearman  0.98     0.00
# Kendall   0.93     0.00
# ------('PROPERTYGFATOTAL', 'LARGESTPROPERTYUSETYPEGFA')-----
#           stat  p_value
# Pearson   0.95     0.00
# Spearman  0.92     0.00
# Kendall   0.79     0.00
# ------('PROPERTYGFATOTAL', 'NUMBEROFFLOORS')-----
#           stat  p_value
# Pearson   0.64     0.00
# Spearman  0.50     0.00
# Kendall   0.38     0.00
# ------('PROPERTYGFATOTAL', 'PROPERTYGFAPARKING')-----
#           stat  p_value
# Pearson   0.62     0.00
# Spearman  0.44     0.00
# Kendall   0.36     0.00
# ------('PARKINGGFARATIO', 'PROPERTYGFAPARKING')-----
#           stat  p_value
# Pearson   0.67     0.00
# Spearman  0.99     0.00
# Kendall   0.93     0.00
# ------('NUMBEROFFLOORS', 'LARGESTPROPERTYUSETYPEGFA')-----
#           stat  p_value
# Pearson   0.60     0.00
# Spearman  0.44     0.00
# Kendall   0.33     0.00
# ------('MEANGFAPERFLOOR', 'PROPERTYGFABUILDING(S)')-----
#           stat  p_value
# Pearson   0.52     0.00
# Spearman  0.72     0.00
# Kendall   0.54     0.00
# ------('SECONDLARGESTPROPERTYUSETYPEGFA', 'THIRDLARGESTPROPERTYUSETYPEGFA')-----
#           stat  p_value
# Pearson   0.52     0.00
# Spearman  0.55     0.00
# Kendall   0.49     0.00
# ------('NUMBEROFFLOORS', 'PROPERTYGFABUILDING(S)')-----
#           stat  p_value
# Pearson   0.60     0.00
# Spearman  0.47     0.00
# Kendall   0.35     0.00
# ------('PARKINGGFARATIO', 'BUILDINGAGE')-----
#           stat  p_value
# Pearson  -0.35     0.00
# Spearman -0.37     0.00
# Kendall  -0.29     0.00
# ------('NUMBEROFFLOORS', 'BUILDINGAGE')-----
#           stat  p_value
# Pearson  -0.10     0.00
# Spearman -0.08     0.00
# Kendall  -0.05     0.01
# ------('NUMBEROFBUILDINGS', 'NBYEARSCERTIFIED')-----
#           stat  p_value
# Pearson  -0.02     0.52
# Spearman -0.01     0.68
# Kendall  -0.01     0.68

# %% [markdown]
# #### PCA

# %%
df[prop_Q_cols].shape, df[prop_C_cols].shape
# Out:
# ((1685, 12), (1685, 8))

# %%
np.set_printoptions(formatter={'float': '{: 6.2f}'.format})
df_pca = df.loc[:, prop_Q_cols].dropna(how='any')
id_code = df_pca.index
X = df_pca.values

X_sc = StandardScaler().fit_transform(X)

n_comp = 11
pca = PCA(n_components=n_comp).fit(X_sc)

pca_df = pd.DataFrame(pca.components_,
                      index=['PC'+str(i+1) for i in range(n_comp)],
                      columns=prop_Q_cols).T

X_proj = pca.transform(X_sc)

# %% [markdown]
# Plotting principal components

# %%
plot_heatmap(pca_df,'Principal components coefficients', vmin=-1, vmax=1, center=0,
             palette=sns.color_palette("coolwarm", 20),figsize=(8,4),shape='rect')
if plot_enabled: plt.savefig(os.getcwd()+'/FIG/'+'2_1_pca_princ_comp.png',
                             dpi=400);
plt.show()

# %% [markdown]
# Plotting explained variance ratio in scree plot

# %%
exp_var_rat = pca.explained_variance_ratio_
scree_plot(col_names= pca_df.columns, exp_var_rat=exp_var_rat, ylim=(0,0.6))
if plot_enabled: plt.savefig(os.getcwd()+'/FIG/'+'2_1_scree_plot.png',
                             dpi=400);
plt.show()

# %%
figure, correlation_matrix = \
     plot_pca_correlation_graph(X = X_sc, variables_names = prop_Q_cols,
                                dimensions=(1, 2), figure_axis_size=6)
                                # X_pca = X_proj[:,0:2],
                                # explained_variance = exp_var_rat[0:2])
if save_enabled: plt.savefig(os.getcwd()+'/FIG/'+'2_1_pca_corr_cir_1-2.png',
                             dpi=400);
plt.show()

# %%
figure, correlation_matrix = \
     plot_pca_correlation_graph(X = X_sc, variables_names = prop_Q_cols,
                                dimensions=(3, 4), figure_axis_size=6)#,
                                # X_pca = X_proj[:,2:4],
                                # explained_variance = exp_var_rat[2:4])
if save_enabled: plt.savefig(os.getcwd()+'/FIG/'+'2_1_pca_corr_cir_3-4.png',
                             dpi=400);
plt.show()

# %%
plot_heatmap(correlation_matrix.T,'PCA Correlation matrix',
             vmin=-1, vmax=1, center=0,
             palette=sns.color_palette("Greens", 20),
             figsize=(12,1.7),shape='rect')
plt.gca().set_yticklabels(['PC1', 'PC2', 'PC3', 'PC4'])
if save_enabled: plt.savefig(os.getcwd()+'/FIG/'+'A_4_1_correaltion_matrix.png',
                             dpi=400);
plt.show()

# %% [markdown]
# ### 2.2 Categorical data

# %% [markdown]
# #### Bar plots

# %%
plot_barplots(df=df, cols=prop_C_cols, figsize=(12,7),
              file_name = '2_2_bar_plots.png',
              layout=(3,3), save_enabled=save_enabled)
plt.show()

# %% [markdown]
# #### Predictive Power Score

# %%
# Predictive Power Score on main features (ppscore)

pps_corr = pps.matrix(df[prop_Q_cols+prop_C_cols])
plot_heatmap(pps_corr, title="Predictive Score", 
             vmin=0, center=0.5, vmax=1, figsize=(12,7), shape='rect',
             palette=sns.color_palette("Oranges", 10))
if save_enabled: plt.savefig(os.getcwd()+'/FIG/'+'2_2_ppscore.png',
                             dpi=400);
plt.show()

# %% [markdown]
# Contingency table showing 'LargestPropertyUseType' vs. 'LargestPropertyUseType' categories

# %%
data_crosstab = pd.crosstab(df['LargestPropertyUseType'], 
                            df['PrimaryPropertyType'],  
                               margins = True)

plot_heatmap(data_crosstab,
             "Contingency table ('LargestPropertyUseType' vs. 'PrimaryPropertyType')",
             vmin=0, center=150, vmax=300, palette=sns.color_palette("inferno", 20),
             figsize=(18,12), shape='rect', fmt='.0f')
if save_enabled: plt.savefig(os.getcwd()+'/FIG/'+'2_2_nutrig_clusters.png', dpi=400);
plt.show()

# Chi-Squared Test
from scipy.stats import chi2_contingency
stat, p, dof, expected = chi2_contingency(data_crosstab)
print('---'+"Chi-squared")
print('stat=%.3f, p=%.3f' % (stat, p))
print('Probably independent') if p > 0.05 else print('Probably dependent')
# Out:
# ---Chi-squared
# stat=26708.350, p=0.000
# Probably dependent

# %% [markdown]
# ## 3 Modelling

# %%
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import cross_val_score

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from mlxtend.plotting import plot_pca_correlation_graph

import category_encoders as ce

from sklearn.model_selection import cross_val_score
from sklearn.pipeline import Pipeline
from sklearn.model_selection import KFold, GridSearchCV, train_test_split
from sklearn.linear_model import Ridge, Lasso, Lars, LinearRegression, ElasticNet, huber, ransac, theil_sen
from sklearn import metrics
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor
from sklearn.svm import SVR

# %% [markdown]
# ### 3.1 Data preprocessing

# %% [markdown]
# #### Features selection

# %% [markdown]
# __Quantitative data__
#
# Excluding highly correlated quantitative features.
# - 'PropertyGFATotal' is strongly correlated with 'PropertyGFABuilding(s)'
# - 'PropertyGFABuilding(s)' is strongly correlated with 'LargestPropertyUseTypeGFA'
#
#
# __Categorical data__
#
# Excluding highly related categorical features.
# - 'LargestPropertyUseType'(57) is strongly correlated with 'PrimaryPropertyType'(29)

# %%
prop_Q_cols_sel = [c for c in prop_Q_cols if c not in\
                              ['PropertyGFATotal', 'PropertyGFABuilding(s)']]
prop_Q_cols_sel
# Out:
# ['NumberofBuildings',
#  'NumberofFloors',
#  'PropertyGFAParking',
#  'LargestPropertyUseTypeGFA',
#  'SecondLargestPropertyUseTypeGFA',
#  'ThirdLargestPropertyUseTypeGFA',
#  'BuildingAge',
#  'MeanGFAperFloor',
#  'ParkingGFARatio',
#  'NbYearsCertified']

# %%
prop_C_cols_sel = [c for c in prop_C_cols if c not in ['PrimaryPropertyType']]
prop_C_cols_sel
# Out:
# ['BuildingType',
#  'LargestPropertyUseType',
#  'SecondLargestPropertyUseType',
#  'ThirdLargestPropertyUseType',
#  'CertifiedPreviousYear',
#  'EnergyProfile',
#  'MainEnergy']

# %% [markdown]
# #### Splitting training and testing set

# %%
df_X = df[prop_Q_cols+prop_C_cols]
df_y1 = df['SiteEnergyUse(kBtu)']
# df_y2 = df['TotalGHGEmissions']

# %%
X_tr, X_te, y1_tr, y1_te = train_test_split(df_X, df_y1,
                                            train_size=0.8, shuffle=True,
                                            stratify=df['PrimaryPropertyType'])

# %% [markdown]
# Training and testing set for linear regression avoiding colinearity

# %%
X_tr_sel = X_tr[prop_Q_cols_sel+prop_C_cols_sel]
X_te_sel = X_te[prop_Q_cols_sel+prop_C_cols_sel]

# %% [markdown]
# #### Feature transformations
#
# __Quantitative data__
#
# Standardizing the quantitative values.
#
# __Categorical data__
#
# Categorical data are all nominal data, none of them are ordinal. We'll choose between:
# - Ordinal Encoding (boolean): 'CertifiedPreviousYear'(2)
# - One-Hot Encoding (low cardinality):
# 'BuildingType'(5), 'MainEnergy'(3), 'EnergyProfile'(8)
# - Binary or Hashing or Leave-One-Out target encoding (high cardinality):
# ('LargestPropertyUseType',
#  'SecondLargestPropertyUseType',
#  'ThirdLargestPropertyUseType', 'PrimaryPropertyType')

# %%
# full dataset
column_trans = make_column_transformer(
    (ce.OneHotEncoder(drop_invariant=True), ['BuildingType', 'MainEnergy','EnergyProfile']),
    (ce.OrdinalEncoder(drop_invariant=True), ['CertifiedPreviousYear']),
    (ce.HashingEncoder(n_components=8, drop_invariant=True),
     ['LargestPropertyUseType', 'SecondLargestPropertyUseType',
      'ThirdLargestPropertyUseType', 'PrimaryPropertyType']),
     remainder=StandardScaler())

# dataset to avoid colinearity
column_trans_sel = make_column_transformer(
    (ce.OneHotEncoder(drop_invariant=True), ['BuildingType', 'MainEnergy','EnergyProfile']),
    (ce.OrdinalEncoder(drop_invariant=True), ['CertifiedPreviousYear']),
    (ce.HashingEncoder(n_components=8, drop_invariant=True),
     ['LargestPropertyUseType', 'SecondLargestPropertyUseType',
      'ThirdLargestPropertyUseType']),
     remainder=StandardScaler())

# %% [markdown]
# ### 3.2 First model selection

# %%
df_res = pd.DataFrame(dtype = 'object')

# %%
print("data missing in colinear" , set(X_tr.columns) - set(X_tr_sel.columns))
# Out:
# data missing in colinear {'PropertyGFATotal', 'PropertyGFABuilding(s)', 'PrimaryPropertyType'}

# %% [markdown]
# #### Linear regression baseline

# %%
reg = LinearRegression()
name_reg = 'LinearRegression'

pipe = make_pipeline(column_trans_sel, reg)
pipe.fit(X_tr_sel,y1_tr)

y_pr = pipe.predict(X_te_sel)
res = scores_reg(name_reg, y1_te, y_pr).astype('object')
res_cv = cv_scores_reg(name_reg, pipe, X_te_sel, y1_te).astype('object')

df_res[res.name] = pd.concat([res.astype('object'), res_cv.astype('object')]) 
df_res
# Out:
#           LinearRegression
# MAE             6492991.36
# MSE     480996005793479.69
# RMSE           21931621.14
# R2                    0.48
# cv_MAE          7406840.85
# cv_MSE  310888173407351.38
# cv_RMSE        16574096.11
# cv_R2                 0.35

# %% [markdown]
# #### Linear Regressions

# %%
'''MODELES REGRESSEURS LINEAIRES DANS SKLEARN : 
Lars, LassoLars, ARDRegression, BayesianRidge, SGDRegressor, HuberRegressor,
RANSACRegressor, TheilSenRegressor, TweedieRegressor, GammaRegressor,
PoissonRegressor, PassiveAggressiveRegressor'''

from sklearn.linear_model import *

# %%
# sans optimisation

for name_reg, reg in zip(['Ridge', 'Lasso', 'ElasticNet', 'Lars', 'LassoLars',
                          'ARDRegression', 'BayesianRidge', 'SGDRegressor',
                          'HuberRegressor', 'RANSACRegressor', 'TheilSenRegressor',
                          'PassiveAggressiveRegressor',
                          'PoissonRegressor', 'TweedieRegressor', 'GammaRegressor'],
                         [Ridge(), Lasso(), ElasticNet(), Lars(), LassoLars(),
                          ARDRegression(), BayesianRidge(), SGDRegressor(),
                          HuberRegressor(), RANSACRegressor(), TheilSenRegressor(),
                          PassiveAggressiveRegressor(),
                          PoissonRegressor(), TweedieRegressor(), GammaRegressor()]):

    pipe = make_pipeline(column_trans, reg)
    pipe.fit(X_tr,y1_tr)

    y_pr = pipe.predict(X_te)
    res = scores_reg(name_reg, y1_te, y_pr).astype('object')
    res_cv = cv_scores_reg(name_reg, pipe, X_te_sel, y1_te).astype('object')

    df_res[res.name] = pd.concat([res.astype('object'), res_cv.astype('object')]) 
df_res
# Out:
#           LinearRegression  ...       GammaRegressor
# MAE             6492991.36  ...          16826910.46
# MSE     480996005793479.69  ... 30808399877630760.00
# RMSE           21931621.14  ...         175523217.49
# R2                    0.48  ...               -32.50
# cv_MAE          7406840.85  ...                  NaN
# cv_MSE  310888173407351.38  ...                  NaN
# cv_RMSE        16574096.11  ...                  NaN
# cv_R2                 0.35  ...                  NaN
#
# [8 rows x 16 columns]

# %%
# Out:
# --- Ridge
# r2 0.44034425023760326
# mae 5899069.537583055
# mse -263904934439643.2
# rmse -13786177.499414107
# --- Lasso
# r2 0.43330491322099796
# mae 5926362.792988028
# mse -264393196980721.1
# rmse -13819777.087215316
# --- ElasticNet
# r2 0.39091048155098235
# mae 5216287.9683406
# mse -292941549260048.6
# rmse -14583331.902772915
# --- Lars
# r2 -192325670.41159528
# mae 36835097141.61929
# mse -2.5443128373385715e+23
# rmse -225588277027.54077
# --- LassoLars
# r2 0.43329989082617154
# mae 5927348.516043048
# mse -264397205747340.16
# rmse -13819876.675935034
# --- ARDRegression
# r2 -0.27246793772073574
# mae 9390702.725098247
# mse -505985647251489.2
# rmse -19787019.687136427
# --- BayesianRidge
# r2 -0.2724679377206471
# mae 9390702.725097582
# mse -505985647251434.6
# rmse -19787019.68713556
# --- SGDRegressor
# r2 0.3851616573795834
# mae 6193323.542263714
# mse -280712541556034.1
# rmse -14344932.913349554
# --- HuberRegressor
# r2 0.42820542842457365
# mae 4466832.874847056
# mse -332565515864445.9
# rmse -14918769.794270897
# --- RANSACRegressor
# r2 -8.721108339791535e+21
# mae 6.978902071811192e+17
# mse -2.696757267577498e+34
# rmse -9.98176849724755e+17
# --- TheilSenRegressor
# r2 0.4735182216565029
# mae 4524119.3989955485
# mse -286483132812954.9
# rmse -14076019.317178141
# --- PassiveAggressiveRegressor
# r2 0.05114201807022334
# mae 6313472.325489862
# mse -469305090082051.7
# rmse -18396137.429433163
# --- PoissonRegressor
# r2 -437.73170520692867
# mae 16371114.046462348
# mse -9.715265667156486e+16
# rmse -196492799.0284496
# --- TweedieRegressor
# r2 0.4255179158399887
# mae 5195206.41493665
# mse -294278408730178.4
# rmse -14467185.866423924
# --- GammaRegressor
# r2 -7769.546813948461
# mae 30858954.603354044
# mse -4.227376984232894e+17
# rmse -375859660.76442295

# %%
# Optimisation de quelques_uns

kf = KFold(n_splits=5, shuffle=True)
df_res2 = pd.DataFrame(dtype = 'object')

alphas = np.logspace(-5,5,2)
dict_param_grid = {'ridge': {'ridge__alpha': alphas},
                   'lasso': {'lasso__alpha': alphas}}

for name_reg, reg in zip(['Ridge', 'Lasso'],
                         [Ridge(), Lasso()]):

    param_grid = dict_param_grid[name_reg.lower()]

    params = [x[0] for x in param_grid.items()]
    list_n_params = ['param_'+x[0] for x in param_grid.items()]

    pipe = make_pipeline(column_trans, reg)
    gscv = GridSearchCV(pipe,
                        param_grid=param_grid,
                        cv=kf, verbose=1)
    gscv.fit(X_tr,y1_tr)

    pipe = make_pipeline(column_trans, reg)
    pipe.fit(X_tr,y1_tr)

    y_pr = pipe.predict(X_te)
    res = scores_reg(name_reg, y1_te, y_pr).astype('object')
    res_cv = cv_scores_reg(name_reg, pipe, X_te_sel, y1_te).astype('object')

    df_res2[res.name] = pd.concat([res.astype('object'), res_cv.astype('object')]) 

df_res2
    # df_res.loc['best_params', name_reg] = tuple([gscv.best_params_[p] for p in params])
    # list_params = tuple([gscv.cv_results_[p].tolist() for p in list_n_params])
    # df_res.loc['list_params', name_reg] = list_params

    # new_rows = ['mean_test_score', 'std_test_score',
    #             'mean_fit_time', 'std_fit_time',
    #             'mean_score_time', 'std_score_time']

    # for r in new_rows:
    #     df_res.loc[r, name_reg] = tuple(gscv.cv_results_[r])
# Out:
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:   12.1s finished
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:   12.4s finished
#                      Ridge              Lasso
# MAE             6291016.76         6320546.14
# MSE     451186206349805.56 449031952935470.81
# RMSE           21241144.19        21190374.06
# R2                    0.51               0.51
# cv_MAE                 NaN                NaN
# cv_MSE                 NaN                NaN
# cv_RMSE                NaN                NaN
# cv_R2                  NaN                NaN

# %%
# Mettre le gridsearch seulement pour le modèle ?

alphas = np.logspace(-5,5,2) # np.logspace(-5,5,200)
l1_ratio = [0,0.15,]
dict_param_grid = {'ridge': {'ridge__alpha': alphas},
                   'lasso': {'lasso__alpha': alphas},
                   'elasticnet': {'elasticnet__alpha': alphas,
                                  'elasticnet__l1_ratio': l1_ratio}}

for name_reg, reg in zip(['Ridge', 'Lasso', 'ElasticNet'],
                         [Ridge(), Lasso(), ElasticNet()]):
    
    param_grid = dict_param_grid[name_reg.lower()]

    params = [x[0] for x in param_grid.items()]
    list_n_params = ['param_'+x[0] for x in param_grid.items()]

    pipe = make_pipeline(column_trans, reg)
    gscv = GridSearchCV(pipe,
                        param_grid=param_grid,
                        cv=kf, verbose=1)
    gscv.fit(X_tr,y1_tr)

    y_pr = gscv.predict(X_te)
    res=scores_reg(name_reg, y1_te, y_pr)

    df_res[res.name] = res.astype('object')
    df_res.loc['best_params', name_reg] = tuple([gscv.best_params_[p] for p in params])
    list_params = tuple([gscv.cv_results_[p].tolist() for p in list_n_params])
    df_res.loc['list_params', name_reg] = list_params

    new_rows = ['mean_test_score', 'std_test_score',
                'mean_fit_time', 'std_fit_time',
                'mean_score_time', 'std_score_time']

    for r in new_rows:
        df_res.loc[r, name_reg] = tuple(gscv.cv_results_[r])

# %%
df_res

# %%
plt.scatter(df_res2.loc['params', 'Lasso'], df_res2.loc['mean_test_score', 'Lasso'])

# %%
import dill
file = open(os.getcwd()+'/P4_df_res_new.pkl', 'wb')
dill.dump(df_res, file)

# %%
file = open(os.getcwd()+'/P4_df_res.pkl', 'rb')
df_res_old = dill.load(file)
df_res_old

# %%
# cross_val_score(pipe, df_X, df_y1, cv=5, scoring='r2').mean()

# %%
# ANCIENNE BOUCLE

alphas = np.logspace(-5,5,300) # np.logspace(-5,5,200)
l1_ratio = [0,0.15,0.3,0.45,0.6,0.75,1]

for name_reg, reg in zip(['Ridge', 'Lasso', 'ElasticNet'],
                         [Ridge(), Lasso(), ElasticNet()]):
    

    pipe = make_pipeline(column_trans, reg)
    gscv = GridSearchCV(pipe,
                        param_grid={name_reg.lower()+'__alpha': alphas},
                        cv=kf, verbose=0)
    gscv.fit(X_tr,y1_tr)

    y_pr = gscv.predict(X_te)
    res=scores_reg(name_reg, y1_te, y_pr)

    df_res.insert(value=res.astype('object'), loc=df_res.shape[1],
                    column=res.name, allow_duplicates=False)
    
    df_res.loc['best_params', name_reg] = gscv.best_params_[name_reg.lower()+'__alpha']
    df_res.loc['params', name_reg] = tuple(gscv.cv_results_['param_'+ name_reg.lower() +'__alpha'].tolist())
    df_res.loc['params', name_reg] = tuple(gscv.cv_results_['param_'+ name_reg.lower() +'__alpha'].tolist())

    new_rows = ['mean_test_score', 'std_test_score',
                'mean_fit_time', 'std_fit_time',
                'mean_score_time', 'std_score_time']
    for r in new_rows:
        df_res.loc[r, name_reg] = tuple(gscv.cv_results_[r])
